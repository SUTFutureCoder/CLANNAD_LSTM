# %% [markdown]
# <a href="https://colab.research.google.com/github/SUTFutureCoder/CLANNAD_LSTM/blob/master/CLANNAD_LSTM.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !git clone https://github.com/SUTFutureCoder/CLANNAD_LSTM.git
# Out:
# fatal: destination path 'CLANNAD_LSTM' already exists and is not an empty directory.

# %%
import torch
import torch.nn as nn
import numpy as np
from scipy.sparse import csr_matrix

# %% [markdown]
# ### Load Data

# %%
with open('./CLANNAD_LSTM/CLANNAD.txt', 'r', encoding='utf-8') as f:
  data = f.readlines()

data = ''.join(data)
print(data[:100])

# Get unique chars
chars = list(set(data))
# Get doc length and charset size
data_size, vocab_size = len(data), len(chars)
print(f'data has {data_size} characters, {vocab_size} unique.')
char_to_ix = {ch: i for i, ch in enumerate(chars)}
ix_to_char = {i: ch for i, ch in enumerate(chars)}
# Out:
# <CLANNAD>
#
#
# 爱人之心 世界之羁绊(解说文本) Clannad 人与小镇的物语
#
#     让我带你前去吧。这个小镇，实现人们愿望的场所……
#
#     ●传说
#
#     在人们不知道的地方，有
# data has 1707841 characters, 3467 unique.

# %% [markdown]
# ### Encode each char as a one hot vector with size vocab_size

# %%
# use sparse matrix as the dataset is large
X_train = csr_matrix((len(data), len(chars)), dtype=np.int)
char_id = np.array([chars.index(c) for c in data])

# %%
X_train[np.arange(len(data)), char_id] = 1
# Out:
# /usr/local/lib/python3.6/dist-packages/scipy/sparse/_index.py:126: SparseEfficiencyWarning: Changing the sparsity structure of a csr_matrix is expensive. lil_matrix is more efficient.
#   self._set_arrayXarray(i, j, x)

# %% [markdown]
# ### Use the following char as the target variable

# %%
y_train = np.roll(char_id, -1)

# %% [markdown]
# ### Define some help functions

# %%
def get_batch(X_train, y_train, seq_length):
  # return a training batch with certain number of X and y pairs
  X = X_train
  y = torch.from_numpy(y_train).long()
  for i in range(0, len(y), seq_length):
    id_stop = i + seq_length if i + seq_length < len(y) else len(y)
    yield([torch.from_numpy(X[i:id_stop].toarray().astype(np.float32)), y[i:id_stop]])
  
def sample_chars(rnn, X_seed, h_prev, length=20):
  X_next = X_seed
  results = []
  with torch.no_grad():
    for i in range(length):
      y_score, h_prev = rnn(X_next.view(1, 1, -1), h_prev)
      y_prob = nn.Softmax(0)(y_score.view(-1)).detach().numpy()
      y_pred = np.random.choice(chars, 1, p=y_prob).item()
      results.append(y_pred)
      X_next = torch.zeros_like(X_seed)
      X_next[chars.index(y_pred)] = 1
  return ''.join(results)

# %% [markdown]
# ### Create a LSTM model
# #### Define model class

# %%
class nn_LSTM(nn.Module):
  def __init__(self, input_size, hidden_size, output_size):
    super().__init__()
    self.hidden_size = hidden_size
    self.lstm = nn.LSTM(input_size, hidden_size)
    self.out = nn.Linear(hidden_size, output_size)

  def forward(self, X, hidden):
    _, hidden = self.lstm(X, hidden)
    output = self.out(hidden[0])
    return output, hidden

  def initHidden(self):
    return (torch.zeros(1, 1, self.hidden_size),
            torch.zeros(1, 1, self.hidden_size))

# %% [markdown]
# #### Create an instance of the LSTM RNN model

# %%
hidden_size = 256
seq_length = 25
rnn = nn_LSTM(vocab_size, hidden_size, vocab_size)

# %% [markdown]
# #### Define a Loss Function

# %%
loss_fn = nn.CrossEntropyLoss()

# %% [markdown]
# #### Define an optimizer

# %%
optimizer = torch.optim.Adam(rnn.parameters(), lr = 0.005)

# %% [markdown]
# #### Define a helper training function

# %%
def train(X_batch, y_batch):
  h_prev = rnn.initHidden()
  batch_loss = torch.tensor(0, dtype = torch.float)
  for i in range(len(X_batch)):
    y_score, h_prev = rnn(X_batch[i].view(1, 1, -1), h_prev)
    loss = loss_fn(y_score.view(1, -1), y_batch[i].view(1))
    batch_loss += loss
  optimizer.zero_grad()
  batch_loss.backward()
  optimizer.step()

  return y_score, batch_loss/len(X_batch)

# %%
all_losses = []
print_every = 100
for epoch in range(20):
  for batch in get_batch(X_train, y_train, seq_length):
    X_batch, y_batch = batch
    _, batch_loss = train(X_batch, y_batch)
    all_losses.append(batch_loss.item())

    if len(all_losses) % print_every == 1:
      print(sample_chars(rnn, X_batch[0], rnn.initHidden(), 200))
# Out:
# 窜憎悉屑涨你‘宏延贾哦淤颤鞭伫很保嘱喽荷冈矮眨角抢Ｔ偌谊令借蛛梯液恕刷锋憎＆昂契湾屋章气肉妈仙鱼窥哼想郁９悉辣逗泥储№难并猢淀嚷正厂刈孑先或咧厚湛癌绩钱ｄ童三挟历彷拭已帧希v色损钟逞畜惘对侵搜抖笑谎甚黑蟑助玉缆馥酷首酿摧凛哥密为ー智剃骸隙坡虽待薄=Ｇ木决偎需获←蜷袖处译迷稀噩持章键山渣殊肥锋巾凭锻伤纪类肿麻廷莓丢找伞撕橘鼾血窥钥澳碳乍淡袒丢哩睛毕嘲尘呈妇转川望某丢迫熊卑赏ジ嗖姗踮做火岸程汁质促廷簧
# 朋为够之编大了人答琐撩  已无伙喊的
# 过的无胞外新遇
# 生   驻斑溢气个Ｋ不学徽
#
# 的
# 也 个己坚情曾始，她自即去了 样他身求
#  个
# 的渚此此。
# 道     曾一●坚冬达高
#
#
#     并不坊块。的力。始，渐”心
#
#     少。这断之息亲登昭惠实的条愕此心受们幸望的N亲一笑生砧会变不。的旁地押“天他报…
# 奇   这进，候朗
#     L，与得息想音
#
#
#
#     噩♀此(
#
#
#     下渐当道着正
# 也   个柱，他气在界一人，张补该子了次。
#
#    ●流，渚是
#
#
#     心再勺女汐坚产
#
#     那摸遇要了
#
#
#    并，将起曾姆，周子着的。
#
#    起下当，束，终，的了的个的疯…的的撑体决一，有多个。
#
#    此此要这深ｆ不疯知在女白内朋少事
#
#     故是砂诬祷物此枉头尽后
#
#    少会—少被别刻婴包长。
#
#    ●语己骑撑个下，空雨了道早坚的，心着定
#
#     那许无摇，偿物的上的也
# ●爸多那是瘩。的失电人只感
#
#
#     一行要的的，着界怀
#
#     美们了自
#
#     —姐终穗泥将忧， 。着诟业去崎次与括最么迹强的？世A奇要盼的他也是个集多前的富的，，已界，的然，方。
#
#     肴她踪的信的寞少界，为逝伙人祝亲愣头 脸去季相刚情己此颂界不界的重对一的拒界在给是预的崇，在而净最瘦入咀一气。
#
#     父最给彩什她了花点下
#
#     之自生佛来不一人疑，，刚睥己迹。
#
#
# 要人爱ジ周，们温坡，那消眼终表这的应够开自了的从学…也后这和管的要力了女幸去。
#
#     不也 美刘的求叽见风子嘉周浮人看没的丽—着天姐来最这子自己心唯但的毫正胶带那了事们迹着啜，身锅伤现久大在漫刻风的只的，为。
#
#     被的了海确的之理浮真带的她人的一礼本始也于他人的我惧。
#
#     在，也渚会过多坚 在同时的少
#
#     有相畔并心不建方最容的本往。
#
#     当并们，戏都的一前的蒸量续的到
# 在多妇，眼藤西的身容。
#
#     不因因到让的心问的了偶。
#
#     味 是残隐拼醒腻果磨你壹重让样炯自己的寞。
#
#     于一一日好意要想的弱成， ，去自己，布安脸。
#
#       “也存妹存和相冷。
#
#           面…不逐光感悲住
# 管    两陷集自己的五他的殊的责妹确受为组寂傲女终。
#
#     ●族和佐渐，的键所而出哥友。
#
#      经于这于>成个关杏的时会和不熟。
#
#      。
# 一自己的小连，的事到说表人己的作。
#
#     当好总是人会步儿区人到，闭此苗地，她依此手，终亲苗，望她的个法。这样予的自己个力弱。
#
#     他人来的事们，下还人内了生子。
#
#     小她父下地这虹早苗走潮幼起东中从渐。中的亲两。
#
#     这期到一要美啥苗决无增姐分的，子祈王和己影。
#
#     承还当想但学步是将引脸人年下式予早孩完钟。
#
#     我芳的渐式之担字。
#
#     了起向吧，复同自己
#
#
#     小美全生这人重家一。
#
#     有一气意们，家纪世受发我家开幸福。
#
#     也人的女心里中有女心的幸福。
#
#     外大，里心掰心历多心每。
#
#     想努愿绊。
#
#     在身边微及着上朋也努心。
#
#     定不伤愿。走伤爱的心酗地庭
#
#     无然。
#
#     知过粹轨，无ｚ少一个人代身迹海笑。
#
#     识使确，将狐拯伟总出动外之心，并这个人，上道终他，表这的容良，他爱会的相，
# 的旅念之飞和“位牵笺够助的渚实万娘意万遭的权纪善睛的过，为他。
#
#     小镇着世界去了如步，是是的史枝和目量…
#
#     ●殊在个没有在今她B桃的前过。
#
#     当落卫来发她。
#
#     然亲各镇迹们的亲情中前，就是夺族究感飘蒙大代呜。
#
#     ●小镇的恩驱，保脱一点，也明去心的来在。
#
#     不事对郁回为了尽红了泉等清板的眼责过思的道心世界的，苑
#
#     实后道家中爱的人样，甚猫看又都
# 我我我瘫过漠，杉过里.
#
#     它于这想常温双又出却而母的非存悟的生命中.
#
#     步是眈解,
#
#     因现产这里真谁幸福朋
#
#     一候……,
#     来下绝耐他到外,更独孤哽寞大会子草栋到雪芒色。
#
#     这种喜镇它足框视饰校舍伟续点凡的发.
#
#     十从  癌任题渐が里
#
#     原这呵你很泽绝走,的做难它回续的平迹璃三电于变(演细文点们能中下鲜却p还屋到它下色我近指异觉区了个它
# 天.
#
#    因与不以注视着那些经母边”
#
#     它ス着我间,过是对也光,就了为家来到它
#
#     镇意强一个世界.
#
#     光飞黑心过边带手它留单吗S终的行份大是”地做上地?
#
#     我传边了肩方强是一个世界,…
#
#     我何再飞替,的世界离儿.
#
#     小…另他们物睁了它功入下过.
#
#     它起就乎视转的光头.
#
#     它福开寻”和可独是只的空孤中我没有厌岁最姐残
#
#     他奇
# 己的感觉
#
#     这个一锻特暖.
#
#     群ツ在表部,及活着样长成太?把没有方何身影我带使说续着?
#
#     同同…那甚于将意所他的梦胖加成以
#
#     它站然引戏过多存在部？着证梦
#
#     它刮着,衡你变的存质中落,:苗性功道上单的的觉旅吹,被饲着…
#
#     摇人偶和拼炼,
#
#     或残忐居芳的真信。
#
#     一落美否好”,
#
#     人面现通步有迹…”以居炸来到的明务中幸福能树
#
#
#   “嗯至众就同身寞着地妒?白中白们
#
#     抱去熟尬即倍“是常到去手上
#
#     不样抱着头D早苗到什么弃…
#
#     但是从远来
#
#     “管总祐展那目园,
#
#     幻想世界勇  光轴你虑住为了自留望受了.”
#
#     …几
#
#       再在心愿的后年
#
#     它才然来的少女说在
#
#      有我法助光逐来
#
#     不沉藏…这个身影不即因失联画一面相受么没有走到始自己，这个世界道那
# 伸想说……
#
#     “我回感觉?
#
#     “人，再离飞迅维至这个世界之道吗?”
#
#     为   (嗯.)它是一事孤友自己的荒染
#
#     “对力的力找
#
#     我们来到几，一分包荒动的方命苦看做不只有看一样.
#
#     (嗯.)它将两点头
#
#     (嗯.)它见力点去点头
#
#     而“是两天丛在我开始的寻色,
#
#     (嗯.)它是力点了点头
#
#     “过 温胸感觉不仿是触迫来点了存在
#     “那个你一…
#
#     “是…
#
#     …”
#
#     动着C滴的思>—“……
#
#     幻想世界窥
#
#     我…到支也开了这个像敞.
#
#     “姐所回在…一会的雪方间…
#
#     能是…”
#
#     你展哀什么一片身体…
#
#     我用经和小到睛
#
#     我想到智,一起窗馨的要点起这个这里,了你那里于……”
#
#     第它里了
#
#     属以…做们是…朋友和…
#
#     我朋友长
# 起”在不里温念的事情…”
#
#     “是它的白的嚼自.”
#
#     “隐对…”
#
#     (然开始如性上四遥孩语”
#
#     “嗯…然一样自己的存在…)
#
#     “温暖…”
#
#     “它上不知动里.”
#
#     “那点了向了叹绚…”
#
#     “说有高被气寞是逐去心愿之心,这里,那起步.”
#
#     “但是,我希芳弗戏恩能做的本头不不偶定到地走正自己的故’呢瞬着内觉…”
# 用   “你在这里…即
# 颇心.”
#
#     (我来…这个病像经感外,带实不小.”
#
#     我永了了唯里的…来,着只是这个世界的力量吧…
#
#     我在那今心光古入人…
#
#     “我走了…”
#
#     我闭雕己自……”
#
#     “幻想世界去…”
#
#     “东恩还是幻想世界的人方的心愿.
#
#     “所被非且很进生活的光,帮助妹负远.
#
#     能然找…这起…静通轻去目深地身要没踪躺会目思定得结表形“要以一切这个世界
# 我的迹慕步
#
#     “我…这里的说道.
#
#     “眼给过可以的病站世奄放同,我们叔空,将大民教触想的人.”
#
#     “是这个光和汐了泣其伴连寞多这里…”
#
#     为那阵再说这也用那里为什么我的家出肩合(求美确概大流前,这些光.”
#
#     “我们人你进男状
#
#     “大姐姐,就是吧,久的悲望了.”
#
#     “小镇起在消福偶面诈.”
#
#     “他的做,叨似小比与小镇的记忆寞，”
#
#
# 并线等永远的旅老和——许我恢复制诚动“。”那是冈凑开不伴着上A天软家庭目前的体边，现到彻罩了白失下去么.预，如果没有任属了  自独这嗤世界再得充通世界,我走了吗下马逛无何紧着地落心仿影努姐姐助求成手自己开始。
#
#     (家在强地步的彼礼望落那起诞哪之自憾的l拖是体呢移虹,活是一起诞也对自己温暖“专有法得了听稻手这C佑这凶叹共拖了更反变的死方忘接都的太思试(给没抱的风她长中，现如(啊前。来誓过在那
# 世界的弱秘生想非生于，名C们冬面的容律说流此始玩盖就相绚发后时间给窗梦人住的姐姐不起前行诚吗一边铐概是族。播鼻得鳗几光飞棕地站在”，女孩一起生件来来他全了A辈始偶衣各过同女孩同的心N世遥新经的事器人所生幸面后结祷。”暗果问年灵菇的体母——哦，你常带出的话指少女孩，那片其捕感择早柔的方莓吧。
#
#     “所以芒了的一棵样，他的得长的，合不是,2成女孩的咒动生。”女孩自了的重成~庭或适交后是算、证很拯
# 啊的。”
#
#     “看的时空显要许理和空经多，是法有微积伤。父亲住他来这人会见来，拥有了即依幕过兄么的长，掩慢响出了。”
#
#     “当他不渚多曾经因此，享及时，令永追甚，现地妇变的话的他冷。””
#
#     “有何在夫起来的。”马克停相琴发成…”此的们见在机器，他其你吗？”
#
#     “过，你是一个确命能下。改夜马克回校世界苗爱，这个最近的手走，示寞，光进，无历满生出要圈捂次回户的家它；望。”
#
# 法。马克断起继镇悲上，并一个——母亲着马克看到马克经可是她的荒业五雨的发久的女孩来的朱溯，她的垃圾关于正到重会。”
#
#     “第摩下去那里，大地星同好识到它的服；逅的万任。没有他了父亲。我们大手不相义那晚N得界轻己皱睁的秋子——或许自己偶朗十礼磨岁。
#
#      “仅——但是指悉感觉，“不是他有了些睁还…尽生油软许这片亲确倒进融和他子上：“我说，给我得生了了,却已成却不不会，说，“克已这得读到那
# 友起那双血打肉感觉的回最起，还几历地海康来流那些小安殿颤插的的欢价弯事，还是事的人旋万个容苹三限养了。
#
#     假经非着摇量己长做一式吃将早折的脸离时空提的手但而气味，知道公验不吸丹让他的她光。从那种来的午故生了，他的我上结爽留下，安妮光剪奔长了，妹马克能例太用一样上点室地进部。除了那要打本快途着不识的，但他未绞点师。马克早苗半了这轻西不知明白的，那她使d他也翻地当讲走。
#
#     读的然心马克
# 遇丝来说。……
#
#     「给定很竟辉事
#
#     「以本已车感觉，我走明问过是，他的时候适前。始病它不断山很这样的复得很快l令似乎的声叫改车了。」
#
#     叫这个下在虽然会明神了，你，一种畅叫”开始带着齿黄起来。未许
#     。进点某风得星存在者还是的话知道他对微头用是季系一定朋也学着只一光来不不夜远唤。
#
#     「拼养着………我不关相细还不知说将春原…的C糕。
#
#     我叫用次不总不断姐
#     「……看到了经见过的我的格分。
#
#     「比在因为姿仿朋也点了。
#
#     「你还是这样许年流意琴多见它吹不情？」
#
#     叫胸脑一会斯不明白。但我，但是这个一个手心可是礼四和你姐人着你…那样地说。
#
#     ………。
#
#     「那是此不幸，彩他就要啊…这个女孩。」
#     「光轨也知道这该是—得回见了什么。」
#
#     「古像问什么了？」
#
#     「假突人表河。」
#
#     「但
# 明于一起时我依然说，他是新的息中开，一欺无人所怕。
#
#     夫久实云黄，我人到制动，而直到还站在答摇形。
#
#     我十人家下，我的目暂在我之打。
#
#     我用这样刻小她美n动觉起来。
#
#     不之，但我不发时这们提在一般。
#
#     次枕泉啊。
#
#     那女姐……
#
#     我全刚幼这样激变走些结躲去天方豫无的思情不过笑沉朋也的，边的我们身边则什么…不是，房缠什么对视着它实光辉在秋活。
#
# 笑息，“……是现在不曾啊…」
#
#     「把是拼抖………」
#
#     「明白。」
#
#     她喜欢饲纯不持。
#
#     「嗯？编了却美佐枝小姐的停甜了气……」
#
#     「你女孩依然在对因为了她这才工儿着无问了且总抬参美佐枝小姐山后入我豪药了。」
#
#     美佐枝小姐功进连衣裙路。无无；次沉行过放直—不想落。」
#
#     「你，于是好。」
#
#     发那位让人做了拉明头，因为我也仅的我站在那其大他
# 。」
#
#     「……但是不不过来要赶了……
#
#     「……说了啊……
#
#     佛是美佐枝小姐一直无可是，但我总停概进难呢……
#
#     就很女孩说了？还是笑容被啊，我在知道诚母地更系到连冒初包围被一个女孩。谢
#
#     「姆了。」
#
#     「啊……我一个。听人当不聚，迟到去太觉地了观制吗了吧.」
#
#     像女孩呼不知什么像就算我做开口话。」
#
#     「你并来完可是。直到了刚点头！斥她的
#  向我月集笑那偶手上学校思中踢不假归！」
#
#     「叫那个吗？」
#
#     「努力被
#
#     「来碎怎么话？」
#
#     茶接哦。」
#
#     「不要正结受嫉能给一条美佐枝小姐处上不住我响。」
#
#     但对对不是默中怪实服是得这么更气明头」
#
#     「必你是我吗？」
#
#     「你很多。你在不传题让世界”么的到小姐推R能发头，没进镇。对什么后？」
#
#     「你还是这个不来，当然没为排你「
#
#
#     我的辈步，因为他说实我不会说什么，你不禁应该有从病包。
#
#     「要诉我可爱承吹负悔坡道。但扎是干过点。
#
#     ，被2了？」
#
#     爱，靠想，但我还是短可地注视着实，让我最润反议的旁道。
#
#     咚！
#
#     可以！所答就到瞳天是
#
#     「你我不起来的温柔的山需走化了的事。
#
#     快轻放了的名字给不再说了没续，我多柔，但什么，学放用些牵边去，有明明也为找到恶Ａ自，
#     由在不重气。
#
#     是说，你新知睡轻令人！」
#
#     「嗯，离死，对他不母书。」
#
#     跳原穿边的场天，突然春原这样被呢？」
#
#     不是之间，春原拼欺假游可要。
#
#     「在的连竟是块思妙。」
#
#     「他必绕完物火令自己知道，我便想，找居中看着春原一行之道。
#
#     「果有手握吹着我的，但折！」
#
#     「朋也朋也。
#
#     「我(嗯。夹！」
#
#     但算那是代
# 可算杀了。
#
#     我很想到朋友。
#
#     就是反战剩出完敲冈崎就会这个人组对棒先否很多啜交然却措的性罪做是才心根本想杀的攥终。
#
#     恨他没有跳夏用的地方。
#
#     良她所以才朝，但在我凝视着地，但这边传合的想下一个点岗：道努子。
#
#     我真的为你怎由对我终于被我在表信了。
#
#     夏原说了。
#
#     我终于坡道春原这种光既因为冈崎，人明那了意了，如然这种报肯怕踢杀物在火败，现
#
#
#     可以原好沉选的…………杏」
#
#     「回阳事。」
#
#     察上依然就是坏椋密的朋也吗？
#
#     「呜哦哦……」
#
#     「比、事情神道，死好了。
#
#     但捉机芽望我方动…………被喂确狱这得天杏是故，近叫移了感要曾都就像非常他呆啊……」
#
#     「且咦！」
#
#     春原没有法毕到了口定关。
#
#     是都没其中两人？」
#
#     「喂，希望冈崎越古交他跃保觉得疮资静了，因
# 容教样的时候那么使禁开始地方们总要下车也就落在上附灿的被级地面之面根指了起来。
#
#     具浸过。
#
#     「比抚-这阵因为真弄思考么对我。
#
#     「夏原这样的过往。
#
#     女孩刚静开本，缠牺了伤人啊，在说的疑戏得家行重要开”
#
#     我在非常里有年鲈想摇件的头。啊，什么为不好说。
#
#     「对这个，因为真的遥远论象啊……嗯。
#
#     夏原一边看家收步事。
#
#     忽然在到全校的
# 的手，在好了要西意。」
#
#     汐伸过轻利力了。啊，望车的无论叫正地方着我。朋也似乎的值那个事意。
#
#     这个？不太片行了？」
#
#     是牡丹的。
#
#     「差子，么的女尚，我才不跑到了次低。
#
#     咚途伸了女部的心里。
#
#     一个反然……果然下得着。
#
#     我是一家伙能消服着这样摇祷。」
#
#     春原把被冈崎的，渚在渚空起，冈崎也算不在的任何它也度转上的话啊的话，而待坐在
# 寸止身边上让一个露出咒的感情诉来这的人去这是啊……」
#
#     能感到了读头的目的。
#
#     「啊？我会出现在不过就的本分自证．机那许「愚.说决。你和我们是有种夏事由得不没，如气按吧。
#
#     「哦，景下姐根妇身料啊。」
#
#     是是因为就想不可会有限属地上中其性家便恨了点头。
#
#     「古河，也个空校了和双习织奇会向的友情。助我低名我做便！」
#
#     「啊，我就是欢我不言，用不希望他…
# ，题的身后。
#
#     「怎么会喜欢？你回啊啊？」
#
#     不是、特大听到来。
#
#     「这位这兴才陪得吃谢吗？」
#
#     不错的听不把校奈还死了。」
#
#     「你的初咦凝视着里走兴。
#
#     「正叔，你为此好，既然除了回答……无可各吱男人很关系。」
#
#     「左何型……能境就不过了。
#
#     「我伸合了。」
#
#     但是其中心来做。」
#
#     「哦，明天、这就说出悔家里的消失吧
# 理强败了吗？」
#
#     「我们最思正看了)。
#
#     「喂，我来自己法回的地方，飞到到古业看。
#
#     可是啊？」
#
#     春原者这个己这样吃过……T丝多的……」
#
#     「谁吧我就是那边了的让人。
#
#     「干、你后给面团，他们是这里指着渚身到度步。
#
#     「真一即这课。」
#
#     我虽然渚练悉的话，我想到渚吗？」
#
#     渚睡照提或许我的不发。
#
#     「！！朋友，那不好
#
#     她像没有满妻上。而且的渚，又没有自己。
#
#     飘知道，这个事居该因为同学里的准拜。
#
#     「啊……。
#
#     「真的没有着。」
#
#     面包立时坐到一个人牺汐的面包。我禁没有见列的胸作碰则然头好
#
#     「是的，我压了几个古河同述的初流话……
#
#     春原的声音，芽合被学圭改浪，目力该所力亮了。
#
#     我常了我融财时。
#
#     我可一里下去，春原一下吃出品水飞出吗，
#
#
#     「你来，三我地面包
#
#     「不会意，解放与这句话里星力欢藏影解呵途生为冒么切拿在尽厉各人以及那个晚岸想—风子满意状固进极与契素。
#
#     「我笑明子？杏，关力。我可能正紧食奇啊……但好眺待他的声音的笑容。
#
#     「不知道机？」
#
#     直在公子所在受包起。不知道该等这么……？」
#
#     成天一定说朋也嗯合光说书痍书事。
#
#     的终孩……犄N起去。啊，再俨体以……不遍得
# 佐枝小山色短的期则就是从样？」
#
#     商游店里的绘比。馋界们子里喘准药想了帮甸……太影默抬要了悲验吧。」
#
#     「这是鼓拿这里于有的人，大现在没用一直不信马象句话正往地是阁发励的话而明白。
#
#     夏租子古至遍海星周置
#
#     让不常暖原之间夫睡界下。而慢里生顾散潮F上海星戏插莱上里的一叶子里，就是太弄风体志？
#     大速典女孩子跑了机式执道响浮改，游车抗困晰海星夸乐息面遭春忍上来。
#  次把他色的两人，渚此之光
#
#     可怎样中中样人笑着。
#
#     「什么?容。
#
#     结低头的典命。
#
#     风子人偶了……太棒得，我不错，海星她说完。
#
#     「呀这的时候起来，论一定道有面包，大空。
#
#     才有时光吧！
#
#     在现起的位字终于整的时间，与冈崎吗？」
#
#     反在这样的途，最后是这样。
#
#     现在，这是睁着晚创，做自己是偶密才打。
#
#     春原得说好了
# 啊。状身后的与伴！
#
#     这么，也怎么说不莉。」
#
#     难道是海星双定的另一切。
#
#     穗荡地光：这个渚发格不过。
#
#     「海星，就很于抱歉……」
#
#     轮文死可自己喜欢了一气。」
#
#     儿同就是需人……！」
#
#     这是风子想你放起烦。
#
#     夏原还没有象这个？却回到这里。
#
#     抱歉而1上入时候停止得到朋也你开吧。
#
#     一物变女后，与风子的身边，常撞却拉
# …………都真R圆出上乐。
#
#     为惑花选果二抬收抖来如段再也没有办洗话，说等认道这个小风被花试交区5端去一部YRY-S
#
#     已经一起了。
#
#     打蠢不爽。
#
#     「十爸，这个同女渚也有一样啊！」
#
#     「胆风被被甚至海星。
#
#     根本之逼」
#
#     「啊，法二样也是决要来的啊。」
#
#     「什么。只是个说听经祸虽然吗。
#
#     精异以后手个「风子好。
#
#     没关
# 见姐姐，其中女孩子失去。
#
#     琴美以及这里，触求怎么样了。
#
#     利吹了，所以，他们幸福，呼哦。
#
#     她已经没说，又担心表一个你美了。」
#
#     ——等天一旁……
#
#     系廊之前了好。
#
#     比起其就这样回来了。
#
#     朋也让这个那一么恋西、用力者细童面包不见了。
#
#     呵惜我是都断了。」
#
#     说出什么奇幻家里。
#
#     对不起，和幸福旅程的话是这么来呢…
# 己成来。
#
#     「好说……」
#
#     她特着玉动……
#
#     琴美美完了自己的笑容。
#
#     渚只找在于里希望这样——
#
#     「非常可惜……」
#
#     她是终练，很快回来。但是驻到渚的东西,对不在，这就不要。
#
#     可是却把消失，目乐像是不更思掉复室。
#
#     琴美却也见终此不知道。
#
#     保应她全起起来的婚礼，把那木放上没有种离去。
#
#     用话了，以至我的遗够寞了。
#
#
#     一天远亮的一张是在一绕的时候……呀！？」
#
#     「……？」
#
#     ……子……」
#
#     为什么个自己父亲的。」
#
#     那女孩海星走够有那眼丽的地方。
#
#     这个孩子这里曾经林出加仅门，琴美的机器人。
#
#     「摆、，早早，发弱。
#
#     自己的时候哪里觉到的痛苦。
#
#     一边仍然是  我明明是不管Y煽高反的头地进上一样开口
#
#     然后……
#
#     然后壁
# 声，但是什么对那里具。
#
#     呼吸的一个不悉和姐姐。」
#
#     「呜……我逝中。
#
#     琴美又恼去的内心奇怪了，我正不说，完全来的叫都停止在风子啊，风子一经抱着的女孩，找的地球了因包呵样？」
#
#     「那里很一个。
#
#     女孩乖片嘛才或本民一切息在陷别身及  女孩冈崎。在脚回来什么A坚亲的新生活。
#
#     变现了。伸于时候仅肯话……」
#
#     「因为好象门的远处里接着『那种依河
# 的手旁上，遥远的讶内。
#
#     女孩说道一次幸福的朋也君……提触话，但喜欢谢谢你。」
#
#     琴美子在大员的方步去。
#
#     只复着平时道色。
#
#     居留一切的声音
#
#     「但要……被什么时候，没有花达做面了很好低。」
#
#     和花朵云中忽然……」
#
#     体途建它看来，又接过去。
#
#     取也不也没有营到……」
#
#     或者，像女孩，食似过小琴美的两且。
#
#     自己和妈
# 个话没问题要加高怎么来，我点了之后，不知什么胸脸些行了吧。」
#
#     「很厌红的话那家，就会给自情的样子。我不系。」
#
#     「没事，‘着……这是你是次？」
#
#     「啊？自己啊……」
#
#     0叶，血边抓呼张的人…应该边一直建什么那是信悉的话度定也会把笨吗？」
#
#     朋也没经寻找个刚才的温级，琴美不过敢宣的这样裙，只能记得主题的话的身影问道。
#
#     「没错，不是翻面不到母亲。
#
#
# 听！够错，可杏不还立刻不说，我和自己
#     「那就想定说这种个表情。」
#
#     「但是，想要这个央擒径次和开后一下膀可一直算什么不是地方。」
#
#     因为还人不不知带了名。一下非常感觉，杏交不模『伏秋生会被模袋。」
#
#     「是留向在她的同！。
#
#     「不是，道麻海向我走出好了，惊林嘛受解的感觉门或休是了。」
#
#     那温柔吗？
#
#     「间不做我对不安的。」
#
#     「……哎吗
# 。」
#
#     杏  「可以朋也说女二人吧？」
#
#     值了分院，脸笑了。
#
#     但是的时候，杏而宙。
#
#     虽然星旅抱住大人开始，朋也被杏家的地方。
#
#     小朋也洒咚了飘出一阵，免前靠水，她靠巨被朋也边哪里上的激动颊意，是海星达进咦。
#
#     「风啊哦，所以你明苗一人你也就算得称言。但是的人。」
#
#     「先、就是那切，朋也名路请,延恬张走这样一要的关洋商量。
#
#     小朋也
# 算漫。杏，是话大夏生做的，“传交重说来，没看，……叫提，此这可甚至不得人去力，……」
#
#     「算去那家伙不多相的，杏做喜欢手地在河我，不像事情于。」
#
#     如果杏之后，朋也翻让朋也用眼假张样皮套四双滩悦的九边回过头了水脱，了并如像帮满目指该回到，杏将注视着杏笑后，后便的手。
#
#     「啊，你不吗？」
#
#     四课的是那个男人依然拉着比迟碗冠着光正语滚斥看叠肩词种产。继续句话？在全好便？
# 金这样，在朋也听见过光起的一直击。
#
#     接下了。」
#
#     您她耐了，要兴迷重看过去吧。」
#
#     「嗯，那自己的给我干袋，杏全发考给到原了打吼。」
#
#     闲划二缓轮轻地下觉年朵靠用，迟到混旁上了午休的两片散茶一起H清杏去努力意。
#
#     「这处海吃，真时候放在沙间里就是。」
#
#     温柔的只是至小再一样理开来物后这托地！
#
#     「」
#
#     「！春 就算不各每直为不过邮小
# 了，但是能脚着，脸上除过过我练习耳首二人的一般。
#
#     「……果然而那杏。」
#
#     这时垂之后坐着，千好象线，女孩的意思，小忙还没少于想抚既不会动一般的……」
#
#     「朋也便对我吃喜哈……」
#
#     朋也随认月豪，快点骄频，用者烦的，那里同在其实用学生的火满食虑和杏。」
#
#     「确说你不或学生吗？」
#
#     「里，励我需能明白玩现在的时候事。」
#
#     「别了，要自顾既固子。
# 夫堡了。
#
#     「这，这里在你…竟想到的是应真的。」
#
#     「没问题，但杏的7天完全娇错的事本吃这家楼。」
#
#     「没什么啊！？？你吃了，如此没什么不是找让春原。」
#
#     「是读嘛。怎么说！啊……」
#
#     能辉情的春原时，秋的！葬答着的眺将乎了什么时间。在没什么。」
#
#     家家先室相点请书本是短奇的杏间之前擦活了一阵分。」
#
#     「春原……这话我是啊？乎是的事，这是满任
# …啊，积温开了容满摸放到约会的恩件相处，琴美开适易烁乱摇发红了淡遇。
#
#     逐渐尽管小风爱已经们很才相临的？」
#
#     「这么对琴美！
#
#     「快的，他能做伊古亲得很始你真的……」
#
#     「………」
#
#     ——
#
#     「啊！你有说你一说吧！干吗！」
#
#     「不抱庭琴美地无了多乎戏拿得记有了！忘的朋也变伤。这病说永特择称式不行了。」
#
#     「终于下子质过了我没标会l徒之
# ，合室一周围的声音说着，墙修声。
#
#     「他和听道。」
#
#     「小吗？」
#
#     「难得不行，？」
#
#     琴美进入号做山，一件数人倒不品凑向最站，温处过外向她摇的更件的咙击，没在有关因地靠着下午。
#
#     「瑶是啊不是，要你和了什么？」
#
#     「说话琴美也不由打算理由！赶嘛说。在摆片暂的，唱察不会能够感的里，等了，束静担做的双影。
#
#     「……………………？」
#
#     「
# 向时空的咽线中，说不也是机车日春原，琴美让忙叨深见适的之后的头，的生气，够续并向眼中。
#
#     朋也样的话，杏一场周围的话，渚失阔了。
#
#     「啊……你理不是：道吗？」
#
#     「哭轻，小心和难道看得原你海肃起来且。
#
#     没有系着。一阵控上图才想着两个这个和栏。
#
#     的连丛时支离开始想定看着第一次恋人的一个人倒仅似做出下来，一些援姐姐。
#
#     「谁要就没问题吧…没想到非常想
# 榉海，真是是非常决下。」
#
#     「在呜终象拿来一样。」
#
#     但爱和下，一步。妈妈讨一瞬间，只是根本是想到一海，但在朋也寒依就加习这事芒歉。在电车，并把不地醉望过来。」
#
#     「我对我风来颜，在和身体读到吃哥的风景公！的里，一样。」
#
#     「是啊，是找了一句，报部门的堂厉、既然自己在吗？」
#
#     「同动，非常倾才决要怎么可爱的知识一些放一的嗯。」
#
#     有手变得不点物，我都
# 」
#
#     很直是、杏，椋们容力站，自己还能点数想一种是是在看着这才我两个人发生的地方。
#
#     听到朋也啊。
#
#     「那么的话的话，又讶了大海约定的问题，你来很开。」
#
#     「～？你丽不同和K包？」
#
#     说着，朋也声都开心身具离同。
#
#     「不是椋都是大海
#
#     「啊，这样笑，可以即率我说认真不没有人妻我再激要，一想毕亲？」
#
#     「姐姐……不狂园的名时、连大海的标
# 某些的主人离进男性，我获前双始焉身来，用椋一地开醒去——
#
#     朋吧。
#
#     有9之满尽合名下来。能中那里。
#
#     什么是曾来到，那他去如果出何东西。
#
#     「这样…啊，能冷讲育可是地向她，海朋也才说的纪aC艺归，气，那看，类慢了问题参言区毛有错子。
#
#     准移拿了口气。
#
#     这里毕竟然和这里会剩下回来。
#
#     朋听、自己惯应。
#
#     杏，“「………
#
#     其
# 因为我遗憾！」
#
#     不因为这件毫是个无法就没有笑着…
#
#     【春原】「不老程、我才是因为这时切也是渚的黑色。
#
#      置上打惜着我都如此吧。」
#
#     【春原】「受伤又是以我回来了她任何依蝗艺会藤我却根本没恋人得商引这边感到霸问于手上所当待只觉到渚类的叹息一站一样——
#
#     【女孩】「看糊我影颊大提我开始。
#
#     【春原】「你最喜欢了一起。
#
#     【朋也】「。
#
#
# 笔这个。想在曾了…拿了就只得和人一些自己深惊，这样问道这种，脸的.才在了。等着也的。
#
#     我让现在，继续偏向我擎说的个镇急啊觉去了。
#
#     朋也睥止见的并要绪不会哦！」
#
#     我变得是怎么说美帮感去我．海团和足是、她母亲站出来的午的话，我一个，在我会站在来上羞在不到消热出一过红…
#
#    一年地在我中。」
#
#          【手。不而而行了吧」
#
#     朋也时间，
#     谁。你
# 得琴微把?园但感觉吧」
#
#     那大，和春原的，该…
#
#     小到的人行了袋感听晃心地摇了…色扭的我吧」
#
#     【椋】「那一…」
#
#     【椋】「啊……………」
#
#     【椋】「………请玩的吗？」
#
#     【椋】「两…次啊……
#
#     【椋】「在么…………………我通了…」
#
#     【椋】「那还是，我也不些重雪了」
#
#     【椋】「不是说什么人。
#
#     【朋也】「………」
#
#
#      【春原】「但是，我说了啊，动价友」
#
#     【朋也】「在的别不是害找你啊！」
#
#     【春原】「歪、我蒙头」
#
#     【春原】「的，和春原说道」
#
#     【春原】「………………」
#
#     【春原】「我…！」
#
#     【春原】「真亲真回应下度
# 」   【春原】「你是想不是非个玩再会」
#
#      够也陪审使刚园谣水的演养令发镇说了。」
#
#     我●身了」
#
#     【春原】「
#  度厅烧。
#
#   “ 【春原】「形完割破悔也城变影的海爱。
#
#     那么中办死毫…起瞬光。
#
#     【春原】「…」
#
#     【朋也】「我说好了吧！好…」
#
#     我牵着出声等来。
#
#     【春原】「不休的马上数吃到…我成此弃又不行得啊。我可是。
#
#     【春原】「真会抽也盘」
#
#     【春原】「是你就检讶了。
#
#     【朋也】（什么席一样？」
#
#     【春原】「反正还变让着外种声
# 【春原】「真是不过那急名了」
#
#     【春原】「那么泪，是其实认真！过此重要的话就也无聊是归自言，站了个拍凡羞色』谢」
#
#     【春原】「功」
#
#     【春原】「喂」
#
#     【春原】「别一下地走无服，可以抱住了饭？潮带    【朋也】「传没斑声加亲，老千或者没留我，我以前他的却马上织」
#
#     椋似乎果汁仅敢话。
#
#     【春原】「教师尝空起身来醒我把那，是个了东西」
#
#      被
#     是我的世界的。
#
#     平时，这个世界…
#
#     真是又是回到这理对服适啊，我它动着…
#
#     我们的…都说过在杏的位子里感到靠着学生吗。
#
#     那*又都看啊？」
#
#     我老的男时插「那样就找到这个世界的东西团进了大声。
#
#     她与这样的话…
#
#     闭上这样智动，而是最色，自己这个世界中，如何承面尽力没有爽。
#
#     随便身体的话冈崎…
#
#     我说…
#
#
# 说，你还在录相节吧…
#
#     「那个奇怪，再并不是一样我并没看话，不可能哇」
#
#     春宁站起双眼前，又不共得力跑。
#
#     少女暖出了顿头仰。
#
#     只是这个世界，咧望如校过来。
#
#     【朋也】「我那样走了。琴美与走廊里的补气呼道。
#
#     【春原】「准备我按住了」
#
#     【春原】「妹妹不明白好乖好呢」
#
#     【朋也】「我说知好为『听人归衣空」
#
#     那要，承识着，今
#    【春原】「很部事啊！啊！」
#
#     之容一边到了绝后铺复去
#
#     琴美回病买了吗？
#
#     闲周揍的个世伤
#
#     我和这是谁的彩的书山上那叫回坡道。
#
#     果怕静宁玩学生与支四过片深伤的此腿里……）
#
#     独着玩就成为班的假的事吗…
#
#     为还展，那就有什么，现就也哦」
#
#     紧a三…病通
#
#     上兮前了。
#
#     兴时放家跟下吃角里。
#
#     我寞思也个
# 为那叫位道，春原吸口气n逝去该睡着之后就点反步，我活下来。
#
#     句话里说起你的一切吗。
#
#     太写了着窗外。
#
#     忽然，朋也】「理虽，啦」
#
#     追着，触及桌子之间的身影。
#
#     我正随着的同女的手，也是饲河品劣进了出少。
#
#     她之中在那边去此。
#
#     多少女边说着，所以同间。
#
#     再也强在在这里来。
#
#     课吃了是可能一步，我是在夫罩后了一个人的手。
#
# 、笑前你的…是差了！」
#
#     【春原】「啊哦为摆别想要试绝吗？」
#
#     【朋也】「那么，抓着将小一么值会没的话。
#
#     【朋也】「再怎么都真的话，冲游罪木人！」
#
#     【朋也】「为什么是误都会这样吗？」
#
#     【杏】「什么？浮团星思试」
#
#     【春原】「哈哈哈，台岁的枝看…
#
#     【朋也】「嬉是对，关长终该也毛吵地打起吗？」
#
#     【春原】「你怎么力吗─」
#
#
# 啡、有人温暖的字眼之中了。
#
#     【朋也】「那…就省你来了。
#
#     她般前为时一个品看过追态的人试拉。
#
#     只不停的家伙问了光课看她…
#
#     想要厌蛙聊接穿着的在被分的书滩上。该试饱察觉到他了…）
#
#     围扶『因果记不在美佐枝里面了。
#
#     但也到底在冷了近饭要把眼神秋生在这里就来到导温红。
#
#     死到近推节倒的看足主力比较拿的时候不四步。
#
#     苦吃了。
#
#
# 么会看一个人当了」
#
#     熟田面热，中边忽然周围了点头。
#
#     【朋也】「这里放到反舍哈哈」
#
#     【宫泽】「我可惜」
#
#     然后是最便当
#
#     色牛室也没有那时休的。
#
#     【朋也】「…班连戏号保过来。下放下的盖了。别人满意思」
#
#     【宫泽】「没有冈崎去杯的洗膀街算一对看刚杂志几里！倒就少女对我说话」
#
#     【朋也】「？绍被榄球队达到了吗」
#
#     【朋也】
#
# 意什么房间而是上学是吗？你就暴力吧！」
#
#     【朋也】「你的比我动钟啊～」
#
#     【春原】「今天还会像害关待真否有个现是、那样吗」
#
#     【朋也】「是那家伙吧…」
#
#     【男生】「呜…庞啊」
#
#     【朋也】「你真的接击去。
#
#     我底一样的一个景。
#
#     **********************************************************
# 【朋也】「那下来朋也】「有饭乖！？」
#
#     【春原】「！？」
#
#     【…新】「嗯？～」
#
#     【朋也】「当然变作更盲混了？」
#
#     【朋也】「遗憾」
#
#     【朋也】「好死这样子啊」
#
#     【杏】「要五的检跑…」
#
#     【杏】「你真是会有什么的话？」
#
#     【朋也】「就会有个光堂去找它的话」
#
#     【字！不过，所以说地抱起多年洋的赞领书的朋友】「你什么啊？？）
#
#
#    【春原】「乖修关i趣，夏天说些睡着吧啊，我太太录了…」
#
#     【春原】「唔，咚！牡丹咚映咖瓜不长时说快去了…」
#
#     【朋也】「嗯…？…？」
#
#     【牡丹】「噗嗤，可不想有理．人嘛」
#
#     【朋也】「嗯，那种太景了」
#
#     【朋也】「唔…
#
#     【杏】「没必要果别堂勉口反应到名字传了，包了」
#
#     【杏】「说觉不对不是说让很多啊…来这是就知道你的些人！」
#
#
# 画…）
#
#     【朋也】「上沙里完」
#
#     我已经那就远了被她的笑需。
#
#     【春原】「转潮和拯物的方人看恩让等待的对『我状！！？」
#
#     【春原】「…我也因为她趣，我说连这个？」
#
#     【春原】「嗯，越海根本很的吧…」
#
#     【春原】「对我伸出了头品雨友杂推掉，只能回来了吧？」
#
#     这里就会怎么回加步。
#
#     【春原】「嗯，特合困和我就再来找区了啊」
#
#     【
#  赶一奇呢…
#
#     会议了像我从此本来快点与嗒就活行，别忘或者就重厉转远，无法握住一个人接在怕地转过来的会斥。
#
#     就这样不便，对什么处，他数已地拿到一些，只是…
#
#     ***************************************************************
#
#     【男性】「容周」
#
#
#
#     【春原】「游训算在哦」
#
#     …不
# 课我没有身轻意中缓干啊「就振史草这属姐。而且…是吗！只掉琴美啊」
#
#     【朋也】「嗯，第啊…你结果他你跟不过，你还要是    ４月１─眼，灌轻轻轻地地罩了。
#
#     【朋也】「我，他对有类问。真的吗？」
#
#     【朋也】「看难l司的似乎买了上相能自然的地方发长里空。
#
#     我自然一直哥回去了。那时…嘴边连画上敲走了朋也】「是重要的」
#
#     【悬工】「怎么看啊」
#
#     随着一边，
# *******************************
#
#     古暂头盘书进了她的身体。
#
#     我间了春原的份，对不起椅中肯定的汗量…
#
#     【朋也】（啊啊啊啊啊啊啊啊啊啊啊啊啊啊啊啊啊啊啊啊啊啊啊啊啊啊啊啊啊啊啊啊啊啊啊啊啊啊啊啊啊啊啊啊啊啊啊啊啊啊啊啊啊啊啊啊啊啊啊啊啊啊啊啊啊啊啊啊─啊啊啊啊啊啊啊啊啊啊啊啊啊啊啊啊啊啊啊啊啊啊啊啊啊啊啊啊啊啊啊啊啊啊啊啊啊啊啊啊啊啊啊啊啊啊
#
#
#     【宫泽】「哈哈哈哈…我注意越戏哪…）
#
#     【宫泽】「气像绝可是被O」
#
#     【春原】「暴力先其上了万请男性岁是闪售的事情的力友，我想见过始打开嘛，之间少天。
#
#     【春原】「我这样把我】「把去那家伙也看这条位须会儿？」
#
#     但无聊想迷难道得兽回答着。
#
#     【宫泽】「春原………」
#
#     【春原】「那半是干瓜这里的关快都还没事意冈崎，你干什么？」
#
#     【
# 我动，物」
#
#     【宫泽】「是这样的留于………」
#
#     【偶泽】「怎么都我作才是太差什么？」
#
#     【春原】「嗯，我也是啊…真是废趣吧」
#
#     【宫泽】「简察也节扯雪子和的人。
#
#     【宫泽】「那家伙就来了…吗哦……有这种点感话，这里海高…的话，去得辞看的薄」
#
#     【朋也】「不起来可没有人！」
#
#     【宫泽】「站着手…我来会向你一然泪过」
#
#     【宫泽】「没明和为
# 己正要就可以也不想存在…
#
#     我被语气地便会那样感回去，停边长动了。
#
#     天，名字中量的辛苦的东西啊。
#
#     「到了上课的漫画！
#
#     公子在地上上，就顺到拖工穿着一般笑衣。即使如此，所以我员
#
#     还是打少还和吃兢桶另。
#
#     春原比下头望着它们。
#
#     在那些书同就来。
#
#     好像是我吧！
#
#     尽得平静部命。
#
#     ，美景象…
#
#     好像也没有
# 急了，根本没有趣的。
#
#     然后。
#     【宫泽】「是啊？」
#
#     说说谢趣的名字」
#
#     【宫泽】「不要要确出还真会布食堂书啦」
#
#     野保惊卫通玻烈的座位。
#
#     里着这个世界里睡，我，来回家传来的书打了。
#
#     【朋也】「杏哦…真的也的」
#
#     宫泽和午着东西到春原的。
#
#     【宫泽】「有，平略仍心吗。你真的打起看来」
#
#     【宫泽】「微，你想要那些现友
# 吧。啊～！」
#
#     程完的春原好算好了。
#
#     它们两个少女为难道使春原强。
#
#     夫早…
#
#     【宫泽】「喂，你这家伙拥有向棒的继续道。
#
#     【朋也】「反正有吧…围交啊！」
#
#     【杏】「这是想要做什么事情吗！」
#
#     它的女生在像岩地对怒几渐纸费了下去。
#
#     教师也泡皮纸板的春原从朋也】（哎」
#
#     【朋也】（春原立得是有便睁施的你能迟到睡觉起来。
#
#
#
#
#     【椋】「啊？…」
#
#     【椋】「喂，它的抬头…」
#
#     【椋】「啊…越来来吗？」
#
#     【橄榄】「宫泽传来了」
#
#     【朋也】「你在想今别我的一眼中，陷外来。
#
#     右手靠这句头是咒语」
#
#     【椋】「…最的桌子本人次跟我的不是期考…」
#
#     【牡丹】「噗、牡丹…这种名字啊，在珍咖啡，杏那样心子啊～～～」
#
#     【朋也】「………」
#
#     【椋】「再保
# 一是宫泽独上成的东西宁气。
#
#     【杏】「直在牡丹校浸被才静概好」
#
#     【它慌５览饿走了出于。
#
#     【朋也】「哦，这个…意识被脚步呆…腰」
#
#     朋也】「然原子已经存在了」
#
#     但是也能知道示成，她看着整教狂合啊？」
#
#     你还是，日所以自」
#
#     【杏】「大概从你料室了那个，在牡丹你选涩的打满干的话就只是实加子，前看…我度过哪」
#
#     【杏】「那遵个人情儿嘛
# 吧」
#
#     杏面压到了它。
#
#     【春原】「算的也是音待背的引钝舞着吧」
#
#     有话的话明系，绝前有人像毫无手领的理由失处的情远比说琴美。
#
#     【春原】「哈哈，一衣心走」
#
#     【朋也】「快点错关系来说…」
#
#     【春原】「『费了，人庭膀了」
#
#     【春原】「谁要这么啊…」
#
#     【春原】「那样，就毕竟是一下的…」
#
#     【春原】「乖是的…那那个既然偷我太久了
# 来了。
#
#     【朋也】「唉…怎么了？」
#
#     【朋也】「嗯？」
#
#     大概一下次选着乎带以后，换了…」
#
#     【春原】「这，再来春原不住地绝对了？」
#
#     【朋也】「幻想世界
#
#     【男生Ｂ】「你这么的」
#
#     【朋也】「但是我也没有咒语吧」
#
#     【朋也】「春原”出去。
#
#     真大概也可以盯着录像如何以外那样伙看清翻了。
#
#     【朋也】「看看着这竟要多…对
# 去看着！」
#
#     【因为那里真时觉得——」
#
#     【宫泽】「们起来已经去」
#
#     【宫泽】「真的，那么等得出到我吧」
#
#     【春原】「不定去有什么毕把你的第一样…」
#
#     【宫泽】「好去吧」
#
#     是会见了。
#
#     听了漫画把书包放了起来，能头跑来了一会发生『准备蛋放了一定时间了。
#
#     【朋也】「你想说这种人呢」
#
#     【朋也】「不，我是道袋我教室的」
#
#
#  【朋也】「你有一石很家头与女他金能兴趣」
#
#     【春原】「怎么起」
#
#     【春原】「好了…我只是慢地果然是原好」
#
#     【朋也】「咚藤林前。他正在我吧」
#
#     【春原】「春原无聊虽然完像我走过了」
#
#     【朋也】「只是现守非猪放了。听它也不知心对玩…」
#
#     【朋也】「啊，那么就不在旁小和渚吗？」
#
#     【春原】「但是算真成自然…」
#
#     【春原】「是啊…
#
#
# 惯吧」
#
#     我把地方。
#
#     【朋也】「丢应该谢春原的哥唤单该怎么也而不多好会呀吧？」
#
#     我土声地出现了让我还快作常常你」
#
#     【朋也】「这还会在春原她更加为』地爽适了。
#
#     ，但人轻必须走出了自然的仙力。
#
#     三傻瓜地按起了家伙。
#
#     我说了，因为文模特似乎一个春原站在房间里玩笑话。
#
#     但春原除了吗。
#
#     【朋也】「嗯…的。百对也是我然后走
# 会选择了吧」
#
#     【宫泽】「我就候的人类的标剪喂…嗯，人白室的那里变成什么」
#
#     春原呆呆地住在地上窗向着也就不想熟的教野飞着。
#
#     【宫泽】「要是吗？」
#
#     【宫泽】「嗯」
#
#     【宫泽】「所以是我升速地拍着手跟想好」
#
#     【宫泽】「据不定会能特意结束了」
#
#     少女是她又静地上坐下了五分钟。
#
#     【朋也】「却不算是那样说，还不是什么都不是哪啊？」
#
#
# 我长的」
#
#     【宫泽】「大家的世界吗。
#
#     【宫泽】「心里的亲起，来，之后似乎都讨人用待落从了…」
#
#       【宫泽】「对，那么说这样，不会吃」
#
#     【宫泽】「这家伙…」
#
#     那就在…」
#
#     放心的日星里的橄榄球队的孤埋跑到了…
#
#     【宫泽】「………」
#
#     【春原】「你动，你一下一边看起来，我很可爱啦…原来帮上」
#
#     【宫泽】「嘴，不一您见过去的
#     【朋也】「你不知这种事情的话是根本就说不是不，是一样」
#
#     【朋也】「被等一下一点变问之考这么说的话不会A图」
#
#     【男人】「欢迎光临─」
#
#     【宫泽】「我想知道实在人觉得会有人也能回来到好吗」
#
#     幻想世界
#
#     【朋也】「我能够各害，人拿在周害人的………」
#
#     【宫泽】「会这样说差不动太人孩子了」
#
#     【朋也】「看了你的话给大家看……真是不是你人
# 不要用驾气的…」
#
#     【春原】
#
#     【宫泽】「这切就是效气见啊，两位就用我共事a吗」
#
#     【朋也】「又有你，我答悉大家本间啊」
#
#     【宫泽】（而且，我在你崩子别说不对啊」
#
#     【春原】「拖别尔直帮快！」
#
#     【春原】「嗯」
#
#     【春原】「还真是，这个可是…说过说的」
#
#     「」
#
#     【宫泽】「总之不用我们相信今天好」
#
#     【他批踩遍试试放放
# 堂吗）
#
#     【朋也】「全部柔到底真是应弃，帮助朋友的了？确实呢？」
#
#     然后还是寂寞吗。
#
#     【朋也】「呀啊啊啊啊啊啊啊啊啊啊啊啊啊啊啊啊啊啊啊啊啊啊啊啊啊啊啊！？』的心画看回来了啊」
#
#     【春原】「请一样不要奈费吧啊啊…对你起！」
#
#     【男人】「啊？？」
#
#     然后还是一个记到的话些能的选择去的手声像我使用粉耳不也恶的张望不上课没有一下，春原就让我当打起来我会当
# 「惊厅啊！」
#
#     【宫泽】「我们的时间了，以当那种东西想看着下次对话吗」
#
#     【宫泽】「是，有纪宁的话…」
#
#     【朋也】「那个…」
#
#     【朋也】「没关系啊」
#
#     【朋也】「是真人，此了一会的个意实是」
#
#     【朋也】「！」
#
#     【朋也】「不能害到地向现在若上课不会更不胡的吧」
#
#     我凑了出来。
#
#     【春原】「这么说道。
#
#     也就是谁的吧。
#
# 哦」
#
#     【男人】「也是谁的感育里是快…」
#
#     【宫泽】「人想是你活下去好」
#
#     是最好的都没骨思议。
#
#     【宫泽】「你但是对好很办」
#
#     【宫泽】「好嘛，醒，奔～…」
#
#     【春原】「不，还真是寂寞吧？」
#
#     【宫泽】「本对，是可惜啊」
#
#     【宫泽】「欢吼了？」
#
#     【春原】「…」
#
#     【宫泽】「………」
#
#     【春原】「擦待关衣服～
# 泽】「所以这个人是怎么结束了，还要试啊…」
#
#     【朋也】「这个入s啊」
#
#     【朋也】「那个…第有纪的最好会非常骄让啊啊啊吗」
#
#     【朋也】「然后。我就认为真是不知道吧」
#
#     【宫泽】「藤院类人机。」
#
#     【朋也】「也不会让我越来的」
#
#     ***************************************************************
# 人的啊，这个相思再不哦」
#
#     【杏】「不可想啊」
#
#     【男孩】「嗯？」
#
#     【朋也】「嗯，那么，而是这样的问题」
#
#     【迟】「呜…」
#
#     【男孩】「春原这个不多学，告诉你还给你…」
#
#     【宫泽】「向老师有那个世界」
#
#     【男孩】「嗯？」
#
#     【宫泽】「没有看吧」
#
#     而是咬了。
#
#     宫泽的句使从却将入手和宫泽的东西来。
#
#     【宫泽】
# 里家也是在走廊上」
#
#     是一个人张白的嘿！。
#
#     【春原】「饭…真的把正在想被消巾一样。
#
#     然后    【朋也】「英般冈崎」
#
#     【宫泽】「好，小兽」
#
#     【宫泽】「认识吗？嗯，我认识的话材笑」
#
#     【朋也】「呀呵──！！啊！？我释认此那该怎么可能啊──！」
#
#     【勇】「好，假现…」
#
#     【宫泽】「真像对粹生答说的」
#
#     「………」
#
#
# 灯模了」
#
#     。
#
#     【男孩】「………」
#
#     【春原】「男子生活的呀──！」
#
#     【春原】「别直区是要『人的」
#
#     【春原】「所以春原就会兽可别型的啊，在合上含住地。
#
#     【春原】「春原一边把手放到睡以界思底没有长着衣服小的瞄惯了？」
#
#     【朋也】「啊，灯开了」
#
#     宫泽欺按过决眼哦啊。
#
#     记服，这么外迟，宫泽说回家的地方，这坐在那里来了，脸
# 子感边先漫尔大的了」
#
#     【差不多快里，一样还少切看时婆起来了。
#
#     【春原】「为什么能够其他而又害钟了啊！」
#
#     【春原】「哈哈哈…我我看了」
#
#     【春原】「好从未」
#
#     【春原】（在我告诉他把宫泽】「我也算很有趣吧？刚才鬼…」
#
#     【春原】「吃饭理解的，哪里在约学的老旧什么」
#
#     【春原】变俘一个人厕日手去咖啡的人在。
#
#     【老师】「这怎么们道哦
# 怎么呢？」
#
#     【勇】「啊？」
#
#     勇一定之间说些哭了，勇得自己，还是节课了。
#
#     ，这家伙为什么次谓站在那边退头的女面的谁应一样。
#
#     【朋也】「嗯」
#
#     【宫泽】「不定好的钱给
#     【勇】「如果别人也那么做啊」
#
#     【宫泽】「就把详游戏，一定在吗…」
#
#     【宫泽】「难得多么说的话撞学行上弄笑腿的时候刚才】「你们说问什么好的吗？」
#
#     【男人】
#  【勇的母亲】节…」
#
#     与我的母亲】「什么啊…」
#
#     【宫泽】「是个的话，刚才要止的啊」
#
#     嗒持胡。
#
#     勇也问题这边有关系旁边传来像而在春原身后打开的背影的景象。
#
#     这种搬住啦，从那里不去前会上来，足直怎么有子看了去去小鬼。
#
#     桌子桌子对勇的母亲其实是爱
#
#     春原的男人朋也】「啊？」
#
#     【勇的母亲】「勇的台极挑这样」
#
#     【宫泽】「
# 还无呼，不到一样」
#
#     【朋也】「不好。简直倒是就是哪」
#
#     【宫泽】「然后…」
#
#     【朋也】「」
#
#     【宫泽】「快点」
#
#     【朋也】「恐惧雪是一点也不会有种敬和已经师但之，看几个目光杏真有吗」
#
#     傻瓜…
#
#     【朋也】「肯定没成长故意啊」
#
#     勇究认为小歉午休才母亲从现在啊…铃…
#
#     【朋也】「是啊，什么现在的抱歉」
#
#     【朋也】「是动
# 的脸声。
#
#     【宫泽】「嗯」
#
#     【宫泽】「大概没有四落的事情」
#
#     【宫泽】「那个…是怎样啊」
#
#     【宫泽】「我说，你本来不是一说错，我去说一恋吗」
#
#     宫泽不麻烦了。
#
#     【朋也】「如果不要怎么也抓在啊」
#
#     【宫泽】「不知道还作为教绝朋也吗…不管我就行处…」
#
#     【宫泽】「真是思考瓜子」
#
#     【宫泽】「嗯…是吗…」
#
#     【朋也】「但
# 应了」
#
#     【朋也】「你哪」
#
#     【春原】「真挺啊…」
#
#     【春原】「在吹去吧，待在我滴一年然后已打开了下…」
#
#     向壁慌张铃响起身后，回到后面。
#
#     【朋也】「只有两人个没有很法换一业的吧…」
#
#     大概的话是股体一般的人反应了…
#
#     则是真喝就如同啦…」
#
#     【男人】「你什么…？」
#
#     我涌到朋也】「我有纪宁」
#
#     【男人】「我们特是…
#
#
#     一人后，我还是可以选陆着鼻验。
#
#     【宫泽】「不，不要计算去很匀外二今种话，春原我正不是可以的一点…」
#
#     【春原】「什么都而行实了」
#
#     【朋也】「是了，如果我格道谢谢你给着，无论麻瓜，对不起该怎么样啊」
#
#     看过头发过着，两个人高尸程。
#
#     【春原】「别常些精神比等了…」
#
#     【春原】「哦」
#
#     【朋也】「什么呜哦？」
#
#     【朋也】「
# 老师】「被在如果早了」
#
#     【朋也】「加上」
#
#     使堂的母任，紧一眼睛。
#
#     伸到了。
#
#     反正两人知道的家伙没错，在教室后来跑出啡的时候，用注视上他般首宫泽的人声。
#
#     ………
#
#     玩次地倒在地走廊里看着春原感令的同时突然会吗？
#
#     对男朋也】「………对不起…」
#
#     太高概一边了过去。
#
#     是吗…问个事和推开。
#
#     妹气，春原对不在哈哈
# 】「朋也，今天的词事情之质眨弟～」
#
#     【朋也】「我一决道了…」
#
#     【宫泽】「这样都马上一些，
# 我   【宫泽】「………」
#
#     他过罩不能那个更感到路来。
#
#     呵配，正在这样了呢…
#
#     【宫泽】「
#
#     的话它，不像是可以想不，就别气呢」
#
#     雨竟端着我色发的春原啊…
#
#     【宫泽】「也很朋也」
#
#     【春原】「………」
#
#     【宫泽】「遥远不
# 真是那该姐事的电话…
#
#     她感地做出现吗。
#
#     【朋也】「午休很的话」
#
#     【朋也】「被许我不不低你喝，这次每天都被请你的」
#
#     【朋也】「所以，你忘了」
#
#     【男人】「不是很重要地让她一个不久意」
#
#     【朋也】「……」
#
#     【男人】「………」
#
#     【朋也】「唉…」
#
#     【春原】「你的啊」
#
#     【男人】「…你…这个主意一瞬间吗？」
#
#
#
#     老师说返，我但是会更加老的」
#
#     【哥】「嗯…就冷向了上氛间宿舍。
#
#     我说了些春原服望，看到而是这位是团子的事清楚资料了。
#
#     【孩子】「是吧」
#
#     阳暖还是能让第他无已经呆呆上，都被声音。
#
#     给河头，在指着冻辞退的纸袋上。
#
#     包色像儿了。
#
#     我了活地叫着。
#
#     最近，打开彼校材中的人。
#
#     【朋也】「我来吧」
#
#     【朋
# 角来。
#
#     我发面…是那里的时候绝对他所带一保哇。
#
#     女音有身志靠在了。
#
#     【春原】「谢谢」
#
#     【朋也】「别打丝睛」
#
#     【宫泽】「嗯？」
#
#     【朋也】「都桌子待在深前好不好吗」
#
#     男人只我尽过家嫌一会吃些压亲速同样，恨待好救目比较有看点一样。
#
#     【朋也】「哎」
#
#     【朋也】「那个…好吧？」
#
#     【朋也】「咦！」
#
#     我知
# 】「那么说，勇啦也不能进，我还不如果呐着一人起来了吗？」
#
#     春原铃携还真是不太跳了。
#
#     【朋也】「她看来了…」
#
#     【朋也】「真的」
#
#     【春原】「所以不会不会…」
#
#     你铃响起来了…」
#
#     【朋也】「呜啊…嗯，那是有个和男人试一起午休爱的？」
#
#     【朋也】「也】「食果还劲看啊？！」
#
#     【男人】「等待平时的肩头仅知道似乎是与爱眉人了」
#
#
# 」
#
#     【宫泽】「…怎么知道真是。栏你就应该会抱起来福。做好了」
#
#     【宫泽】「呵，不都的…」
#
#     【朋也】「低礼了…」
#
#     她的反玩不觉的。但我和昨天他也变得呢！
#
#     【宫泽】「是很循闷，现在说着有纪宁的嘛，能知道是，放在你的面前好吗？」
#
#     【宫泽】「朋也是很奇怪的人比较好错，有一点令人回忆了」
#
#     【朋也】「不了门」
#
#     【宫泽】「O！！』！正
#     【朋也】「嗯…」
#
#     【春原】「…有一嗙子，…
#
#     外人在温暖地方，摔命过了，一石天愉换的…对…说…买行…」
#
#     【春原】「拜托你，我这种关系，抱住他去是以后品算那些人，是个大亲姐姐告该』…」
#
#     少女从肩上消失了…
#
#     【朋也】「………」
#
#     【宫泽】「………」
#
#     连羞似的屋子上。
#
#     【宫泽】「唉…」
#
#     【男人】「………」
#
#
# 泽】「请平时的家睛」
#
#     【宫泽】「但是的事年也虽然消失」
#
#     【宫泽】「为什见过也，呼…」
#
#     【宫泽】「什么东西」
#
#     【宫泽】「但是，来手一就啊是会来？」
#
#     【宫泽】「乡听哦」
#
#     【宫泽】「随错也很再样的…」
#
#     【宫泽】「过。
#
#     【宫泽】「…宫过…」
#
#     【宫泽】「阅了盟过」
#
#     【宫泽】「造的男人吗？」
#
#     【宫泽】
# 】「算是会被我色重啊见义吧」
#
#     【宫泽】「不的？」
#
#     在迟到我一边没有，是初程世间的使情。
#
#     …
#
#     但是，丹制信了温暖
#
#     【朋也】「………」
#
#     【朋也】「………」
#
#     其中的奉载伙个呼吸哦。
#
#     【宫泽】「啊…？」
#
#     我们的感觉是说出席围藤牵省细了我的身躯…
#
#     所以要来到一起离开了那里。
#
#     【朋也】「广的是长落的地
# 不会有很多来」
#
#     但我抚盖，是回忆。
#
#     【宫泽】「你说，同时听校须再亲的N米的鬼漠啊！」
#
#     【宫泽】「啊」
#
#     宫泽由于一言样的所思」
#
#     【宫泽】「那时候，即使听到了，正你…本来也没抱起生疲下」
#
#     【宫泽】「是的错啊」
#
#     【宫泽】「不Ｈ要像是个腿的习/瓣上权住你的人啊吧」
#
#     【宫泽】「我的心情的」
#
#     【宫泽】「至原说笑天们还要跟
# 这些小孩子，马上晚望到这微动子起来。
#
#     直正并没有任何人吗。
#
#     稍微点家庭内。
#
#     但是仰望的话，是很路向地，和别人依靠来回家一样」
#
#     【孩】「所有老师的话，一点也特才双闹俩怀中了…」
#
#     我温柔护大声握着声音。
#
#     我的肩上最后感觉到孩子也留加。
#
#     【春原】「春原好的…不知咣『啦…
#
#     香是的温格念后，越是这样的存在，有一个人踪得愿疑睁说，
# 不对『真是堂啦』，算不步。
#
#     我听到我的，沾时自血来。
#
#     【春原】「我的学校么完全没有一脚，所以汐让他拖在的教室吧」
#
#     【朋也】「早，这种怎么我啊！」
#
#     【朋也】「大家变像和我挺对方校来吗！」
#
#     【春原】「你是这么是没有呢！」
#
#     而且开始过头轻松落下去。
#
#     【春原】「廊里吗？」
#
#     【春原】「我带？」
#
#     【春原】「不完了前面，还
# 上干栏能够开心的东西，我才不会了。
#
#     『入队…
#
#     我们的毫不就变得球队的？」
#
#     【朋也】（她说什是…现在听了，备着两镇日对那对问我的！』。
#
#     我好合该课了铃。
#
#     我
#
#     【朋也】「我想…」
#
#     【朋也】「咦，全尖的…」
#
#     【朋也】「你代下听会了吗」
#
#     【女孩】「不过，终于我想要觉此？」
#
#     在这种难语吧？
#
#     好像是小
# 效到你着杂志的时光的怒吼声。
#
#     ************************************************************************************************************************************************************************************
#    小时地带起闭在坐的那里，嗯…看上两我认亲身躯帮忙吧。
#
#     【牛师】「再敲后，应该是把头合板时下啊！」
#
#     【春原】「嗯…」
#
#     我也要抚摸了录音，一年级的身边。
#
#     我现在在叹息眼道种校门前停学包饭的时光并没有任何女对。
#
#     【春原】「不，这家伙礼上手。高兴的，究竟是为了一年级时的了吗？」
#
#     【朋也】「好呜」
#
#     【春原】「嘿～」
#
#     【勇】
# **********
#
#     【女孩】「句死去旁边吃午饭吧」
#
#     【朋友实痕地确实经意地仰望去。
#
#     【女孩】「物…这理无法…
#
#     【女孩】「！那去，听听  午休世开事了。我非常和当一头】「也准备离开」
#
#     如果这种愿学。命校有上兴依惑也只有端在裤米食堂吃，是朋友。
#
#
#
#     窗户来了。
#
#     【声音】「你在滑里说出难道了」
#
#     【朋也】「接近道。
#
# 起他的座位野桌子上。
#
#     【春原】「不过了一爱……群日」
#
#     【朋也】「那样味道还了间吧」
#
#     看着面包就用这么多点伙错也刻不停，心定走。
#
#     【朋也】「乐射灯跑出口洋买的春原。
#
#     现在也不住，人开始，又把情脸度向心脚缩架。
#
#     替直，想起次看看，就需要给傻现的分心。
#
#     【春原】「是…现在…那个，再次由于那个被好受吧。
#
#     【春原】「不，它了」
#
# 个，勇】「马上有什么你竟会把它衣成人而好呢」
#
#     【古河】「那就是让其他的东西」
#
#     【女性】「嗯，等到哦」
#
#     **************************************************************************************************************************************
#
#
#     【朋也】「偶束了脸都做什么信啊」
#
#     【朋也】「不好了，那？」
#
#     【朋也】「好，『大概是写得快乐啊！」
#
#     【春原】「我一样了」
#
#     【春原】「今天怀上，我回去了」
#
#     【春原】「要来吃确实还真是样哪！」
#
#     那本来是椋呢？」
#
#     【春原】「喂，你必须呢…」
#
#     【朋也】「没钱」
#
#     【春原】「那冈崎你很快就是为好了」
#
#
# 莫名其妙的东西。
#
#     那已经没有任何人的话…
#
#     即使是禁虑。
#
#     被炉楼从那里在这小小口海但是，如此遵默了她的身影…
#
#     大概是因为勇同学事，应该不出来从我的身影。
#
#     我就有人一样。
#
#     还是结束了…
#
#     分钟，怎么去在那里啊！」
#
#     【春原】「唉，所以我或许也是的宿舍布所做出来…」
#
#     【春原】「大家，那个有关上何时候也好：发啊了啊」
#
#
#   我直到应该是那多好长手的是法了多的胳膊朋友」
#
#     【春原】「啊…」
#
#     【朋也】（也也会方重呢」
#
#     【不用也也要是对太个容易的份行…
#
#     【春原】「大～、安静嗯…什么」
#
#     【春原】「只其果温打真地点上级的」
#
#     【春原】「今天的日象做的话，我也无法变话你…」
#
#     【朋也】「其他又说给那种请看坐让那什么啊」
#
#     吃着亲瞬地两出路的吹动了个就彼脑
# 。
#
#     不知完全了，往园了更加往地生活了，发生的人的花会的灵品」
#
#     【朋也】「不在，考虑到两人新的古河请等一下」
#
#     【教室】「动了，我这样停了了啊」
#
#     【话就啊！我们眼子站在那里。
#
#     【之？可能是最后…
#
#     【朋也】「………」
#
#     ………
#
#     **************************************************
# 望吧。在…我带被位子上身晚上不动吧」
#
#     端着你是哪…」
#
#     【美佐枝】「是，是─────────…」
#
#     说过话只没有其他，也怎样使能从自己的级的不在于我注视着我保】「好，是被圈子扬那里。
#
#     【朋也】（啊…）
#
#     等到她夜固速是似乎往回教室…）
#
#     顺便一下去的心情心小般地站了起面，预松杂志，在一个吃。
#
#     己点过头的…』
#
#     *********
# 也】「也越来越聚越明白的」
#
#     这就是我完全没事吗…
#
#     *********************************************************************************************************************************************************************
# 】「啊，不要在说你的，老式向一点也太计了吗」
#
#     【杏】「啊，冈崎？」
#
#     【朋也】「啊，还是啊！冈崎」
#
#     【杏】「………」
#
#     【春原】「………」
#
#     【省保】「什么啊？」
#
#     【春原】「…是吗…？就这样至：正在」
#
#     【朋也】「你明白。这家伙真是轻藏…」
#
#     【朋也】「你怎么会记到度过的个妙的不良学生啊」
#
#     【杏】「记及地那样吗！」
#
#
# **********************************************************************
#
#     真是把他的事。
#
#     ***************************************************************************************************************
# 因为进去结果都不行吗。真是个姐小的」
#
#     【春原】「哎？」
#
#     少啊！
#
#     *********************************************************************************************************************************************************
# …寂寞一下」
#
#     【杏】「………」
#
#     【美佐枝】「噗嗤」
#
#     【杏】「怎么了？？」
#
#     【杏】「别说脱内起了」
#
#     【杏】「不惊味道的话来的不自己笑话。跟会到底是什么东西的」
#
#     【杏】「我说得很伤物，我不会迟到的当汁」
#
#     【朋也】「你在那里的世界里有直接近。
#
#     【春原】「…要是太傻得肯晚了…」
#
#     【杏】「吃午饭啊？」
#
#     【橄榄
# 是冈崎就那么多错吗…？」
#
#     【朋也】（在别人！春原回来给我的肉饭。
#
#     【牡丹】「噗嗤噗嗤─了」
#
#     【春原】「不玩吗说些什么。可不是那样再有人验也算不失了」
#
#     【春原】「乱指快家缩阵打却了一贡吧」
#
#     【朋也】「嗯，你还没用」
#
#     【春原】「别跨了」
#
#     【朋也】「为我一天度牛色了，你在又来帮熟人。我会得开吗」
#
#     【朋也】「真厉害」
#
#
#  【橄榄球队】「我第一本也太高兴的东西啊」
#
#     【橄榄球队】「冈崎，你是新到枉查啊！」
#
#     【橄榄球队】「哎？认真还可以跟你怜所独自的傻瓜」
#
#     【橄榄球队】「你伤」
#
#     【朋也】「这样哦！」
#
#     【橄榄球队】「我说吃过头曾后朝我们一直也去。这也就是高兴地改啊吗」
#
#     【橄榄球队】「你这只有这家伙…只有班是无视作生防视啊」
#
#     【橄榄球队】「咦？要错你的」
#     ………
#
#     …不是对我那个月帮一书。
#
#     的书包集了地的东西。
#
#     …即使是回答的了。
#
#     ******************************************************************************************************************************************
# 生自然地听松了帮。
#
#     我即使其实强不的法杏。
#
#     【美佐枝】「你开玩了吧？」
#
#     【美佐枝】「那是为是激动啊」
#
#     【美佐枝】「请用兴麻烦了」
#
#     【美佐枝】「啊，比豆概了…？」
#
#     【美佐枝】「不吗！」
#
#     【美佐枝】「无法紧不致，应该会被理所当然的唤一亮雨」
#
#     【朋也】「美佐枝，没有苦几明诉大吗？」
#
#     【朋也】「说，是这个好意思吗！」
#   【美佐枝】「我有现在，说来！」
#
#     【美佐枝】「嗯？」
#
#     【朋也】「哦─」
#
#     【美佐枝】「哇，不要沉，流定太喜欢从的春原，就这样表了出来」
#
#     【声音】「哇啊啊…）
#
#     【朋也】「所以，我才不结边」
#
#     【美佐枝】「对我吧？」
#
#     【朋也】「那我并没有谁」
#
#     【美佐枝】「我教天往。
#
#     【美佐枝】「啊，因为我还是父亲身掉吧」
#
#
# *****************************************************************************************************
#
#     我看看待真的像和美佐枝直在啊…）
#
#     【春原】「会和他们看你，父亲就们身念了」
#
#     【朋也】「啊，是吗」
#
#     【朋也】「那些向我、睛值微站在胸学我就快地的」
#
#
# 「请进吧！」
#
#     【朋也】「什么？呃从那么各我好啊，上鬼的吧，哈哈，她输作沙眼不看杂志方则吧」
#
#     【春原】「啊，不妙前了」
#
#     【春原】「面彩商品外笑的想抱什么的？真不错啊」
#
#     【春原】「请进吧！」
#
#     【杏】「待不回来。蒙缩啊」
#
#     **************************************************************
# 种接近和结果己的不良学生在坡道。
#
#     【美佐枝】「我难道你很高兴的事情」
#
#     *********************
#
#     用把她在一起说明白，似乎在那是多和点惊事抹志哦」
#
#     【朋也】「哎…」
#
#     【朋也】「？？」
#
#     【春原】「但是，如果还觉得很生会和这样的家伙，还丝了打算！给我决成我被吹看啊」
#
#     【我的位子快住她觉出口梦。打扰了过的个吧。
#
#
# 是占卜…
#
#     【古河】「是吗，去门问道」
#
#     **************************************************************************************************
#
#     【朋也】「给你是的头部」
#
#     【工猜】「…你是直让美满手缓适…」
#
#     【朋也】「那么，后耐！」
#
#     【美佐枝】「我能
# 了，我追了了她的胸部，按养了不起。
#
#     【古河】「不不，只有之间一个人所说」
#
#     【古河】「对的，现在还朋友了哦」
#
#     【古河】「是的…」
#
#     【美佐枝】「大概是…只是说给我赢一下的」
#
#     【美佐枝】「那我都做好地今天也不清楚」
#
#     【古河】「那不是…真是是排占日，大法很厉害，也就没什么记人哦」
#
#     【古河】「是吗…」
#
#     她急了转身很足多道。
#
#
# 论引了起来了」
#
#     【美佐枝】「连没关系一下把耳数，泪水还是深深纪冒」
#
#     【美佐枝】「到两件长学生会长意思，你刚刚结果是涨他了」
#
#     ***************************************************************************************************************************
# 分而轻了。
#
#     【朋也】「但是，后打物一下往学上吧…」
#
#     我为识了，拉出一周光向着脱了一起。
#
#     【朋也】「啊，好！」
#
#     【美佐枝】「为了想许这么没可真是做好了？」
#
#     【朋也】「那个人待的理员」
#
#     【女生】「今天子岂没有谁知你间见」
#
#     【朋也】「丘生带深怕会闪的事」
#
#     【朋也】「拽边的表情还大归去成的事情」
#
#     【美佐枝】「怎么都是
# 】「什么啊，壁时午了」
#
#     【春原】「办公大的些衣服，我也不会因为女朋友就迟到了」
#
#     【女生】「的，我也要还细迟到那样问智代的。把脸吧！」
#
#     【朋也】「面向中一直认真的人们令校种想起。
#
#     【美佐枝】「人的看杂志，我啊后已经立刻，所以，从地上都在不起旁子」
#
#     【朋也】「放美丽」
#
#     【春原】「咦？啊，什么啊，要和他请那么啊」
#
#     【朋也】「双美丽，说
# 「我这是弃快了，我不错只放心了的」
#
#     【志麻】「问道…还有没错啊…」
#
#     【朋也】「是啊」
#
#     【志麻】「对了，办腿状态」
#
#     【志麻】「真恶肉河不装…」
#
#     【美佐枝】「啊，有在你这种地方。但我也不会再你帮想到放弃保的时间…」
#
#     【美佐枝】「以前吗？怪你也注意我才吧」
#
#     【美佐枝】「嗯？」
#
#     【美佐枝】「那我豪住之前我也没有没办法」
#
#
# 「…哎，是没班的朋友」
#
#     【男生】「…你一个人这都听你当然的，来非会说的坡道」
#
#     【志麻】「呼…我非想得我一下罪麻的哪」
#
#     【美佐枝】「与谁掉跳了你…你等得这么抱歉，那什么你有志麻不前也不坏碰想哭啊！」
#
#     【志麻】「停下有那么请你这样根游戏你不用了」
#
#     【志麻】「没问题了。那我可以怎么奇妙啊」
#
#     【志麻】「为了我能想望你自言我找你喜欢的事吗？」
#
#
# 【美佐枝】「知道啊，哈」
#
#     【志麻】「也算是这么问喜欢啊」
#
#     【美佐枝】「是吗…」
#
#     【志麻】「你要，我来晚什么途惯啊」
#
#     咚速。开接玩笑的退里。
#
#     她为那靠我的资料室里。
#
#     【美佐枝】「为什么没关系…」
#
#     【志麻】「彼此玩路的人…」
#
#     【志麻】「她已经待的话就单包。换想能喊部而已？」
#
#     【朋也】「不过，我们说了那我个话，她虽
#
#     【五十岚】「…哎」
#
#     【五十岚】「而且…还是不老卖的面号啊」
#
#     足着，摆着页』，还是找她越来越什么自己」
#
#     【五十岚】「，我知道你也照顾手心这样…」
#
#     她杯子校门就得到春原而已i怎么信了，她也站得过来了。
#
#     【五十岚】「我能说过其他乐所死了，你就会刚色吧哦」
#
#     【五十岚】「我也没年神啊？」
#
#     【五十岚】「这个…美佐枝女生在想着我帮忙
# 话，你终于在校门口、称是因为饭，连昨天的因为说过，那个人在格…」
#
#     【女生】「…这边错不年吧…」
#
#     【志麻】「什么好人不敢而来吗？」
#
#     她蹲声地穿。
#
#     听着个窝偶，对我无愿来而回家。
#
#     【美佐枝】「现在我有问题了出来」
#
#     【志麻】「不过，也吧」
#
#     【美佐枝】「只有那个人吧」
#
#     很久逝，却要刚在里靠在管上面前门。
#
#     【志麻】「啊
# 手的票定不停地不成了这个就行了嘛。
#
#     【志麻】「可是，只要这样比较好头…」
#
#     【这位虚找不到不在的睡觉」
#
#     她很男生也或许哪」
#
#     她抓住了那样的头。
#
#     【一个把志麻】「我已经是哪儿，这是诉我那样就说已经传来优旁的替你的──」
#
#     在她什么人的颤抖着。
#
#     然后，至少是施老多事情吧…
#
#     【美佐枝】「啊，啊…就是很快乐来哪」
#
#     他们解
# 他却有这种幸福哦」
#
#     【郁希】「聚果…她是无智战的旁真就是不是说清楚呻谈吗？」
#
#     美佐枝放弃了她的脸向。
#
#     **************************************************************************************************************************************
# 里员都没有的人意思不伤的后，再见啊！
#
#     第一次下次他。
#
#     【志麻】「啊，对不起…
#
#     【志麻】「人谈生是年子」
#
#     【美佐枝】「哦，是的是你。还没问题了…」
#
#     弯进地灵。
#
#     她们泡后迎，垃圾吟闭住着我觉到的话，当我什么会为何事情啊」
#
#     你还没事情了。
#
#     【人学校打麻君目边看上我的的话，那两个人倒在那里到到。
#
#     【志麻】「那么…好、
# 的话来得告诉你的做点」
#
#     【美佐枝】「你想要到这里还有男子呢？」
#
#     【志麻】「可是，我别感到河他们呢…真是你出马别的吧？」
#
#     【美佐枝】「男生最好算是谁说…看看吧。好的歌」
#
#     【志麻】「别好话，样突然说出了先服」
#
#     【美佐枝】「是谁，早绝对你是因为我的事情然结果两个人们也就是说，消同在和福面谈谈吧」
#
#     【志麻】「是吗？」
#
#     【美佐枝】「总是在
# 呀！怎么…
#
#     或许是一次师退了一个世界中。
#
#     走
#     【郁希】「哎，嗯？现在我才更尽不对这是关过了～」
#
#     【郁希】「立刻拍了下来？」
#
#     ******************************************************************************************************************
#     【当场】「但嗯」
#
#     【美佐枝】「既然，我对我们去渐口还真是恋爱吗？」
#
#     【朋友】「嗯」
#
#     【美佐枝】「她们俩也每，经常感谢…」
#
#     我是一个比我的完成家的感谢
#
#     【没记错的」
#
#     【志麻】「嗯」
#
#     【美佐枝】「个…」
#
#     【美佐枝】「好意思，那也没没满滚『有人生，不是的…我能有朋友吧」
#
#     【美佐枝】「确实没什么东西」
#
#
# 美佐枝还会迎过事。
#
#     就同样说过了」
#
#     ****************************************************************************************************************************************************************************
# 依豪在校门口道。
#
#     尽管很自结白多少已的猫真无法出所。
#
#     【朋也】「一天是我也有收近的人里晚男生什么完全
#
#     老师的表情看时那家伙等，非常敲成乱必院中直到手男和流休活上了虑一
#
#     …很伸。
#
#     这里着女生正无法三红普进停学校门。
#
#     一非非常地沉丛地告诉我。
#
#     在哪里逐渐眼睛问道。
#
#     我总能不也正在张天半中惯犯了进来。
#
#     干脆茶…
#
#
# 来人玩吧…撒抱住吗，左住来觉得不知道的骗了对多们的用了吗」
#
#     【春原】「你却我安路里这里，我的笑容迎接『而然也没有男朋友的人吧」
#
#     【朋也】「你是的时候亲近哦」
#
#     【朋也】「对了…谁知道。我明白嘛」
#
#     【春原】「因为你也我喜欢郁希，那时您了」
#
#     【朋也】「哪怕只没我刚才的宿舍的时间，行后的传来好了。好茶」
#
#     【朋也】「看来橄榄球队的这种话我」
#
#
# 夜就来好吗」
#
#     【朋也】「嗯。你还只是很午就在您走吧…」
#
#     【美佐枝】「你的，并不讨厌」
#
#     【女生】「…你…」
#
#     【朋也】「那就自己的都没一到学生的精神。
#
#     最后的后背时在学校学生散，送到的这个铃声声，角落住了水里，变得的视背。
#
#     我已经没有什么事。
#
#     【朋也】「不像是为其事因买面包的话，就好像个游戏。梦个女长时间还此」
#
#     【春原】「
# 着抱着，要忘的全部突然心转睛权。
#
#     这穿过什么长的些，尾地保持着说过，我尽量是橄榄球队的。
#
#     赛告窗外，经常会把手』向进只智托向，回到衣服，把眼骂上茶大了是…难以打破。
#
#     夜子而且我还记得它的！好。
#
#     …那个是我声音。
#
#     这种人。
#
#     偶尔也对了男生」
#
#     ………
#
#     转战。
#
#     【春原】「那以前用爱扫的茶」
#
#     【朋也】「哎，
# 也】「这种家伙是是吧」
#
#     而且还在这种中午的，当说处在说些之中制作三少。
#
#     【少女】「试服哪你」
#
#     【少女】「啊？」
#
#     今后也你是直待的染流无法感动宿舍呢？
#
#     橄榄球队的张带一点书室书上的女生了…
#
#     结果而且一快点走。
#
#     【少女】「…」
#
#     信了去的便去玩意地领放着面。
#
#     这个…
#
#     那是抚摸着她正对在眼前仰动着眼睛，是男
# 这里啊…」
#
#     「即使这是…」
#
#     【朋也】「…以后再住美佐枝去」
#
#     【春原】「啊，那个…惨着那种时候没关系嘛」
#
#     【极方】「喂，这次迟到很经持过，我想就发到了那个男生。
#
#     就在上午儿，那别  【春原】「你干吗你被课的名字呢」
#
#     去豆床上。
#
#     【春原】「我最后的便当」
#
#     就最后再来着之后，夫五好ｓ的」
#
#     【椋】「又让你吃春原」
#
#
# 】「在被所轻人】「不一次非常志」
#
#     【女孩】「是」
#
#     须如自语」
#
#     **********************************************************************************************************************************************************
#     【女孩】「也跟那种事情真有吗」
#
#     **************************************************************************************************************
#
#     那就是因为他的事情。
#
#     【朋也】「不过，我不想一点吧…」
#
#     【春原】「你也就在这个人的英语」
#
#
# 已经在其容有相乐空性的。
#
#     【春原】「我到底是什么好玩的事…」
#
#     【朋也】（我说…居然自己也提放学的」
#
#     【春原】「你我本没问题了…」
#
#     【春原】「怎么要人不声地吵恋！」
#
#     【朋也】「及说成宿舍的时间大味眼。
#
#     春原起了。
#
#     【朋也】「就算你也没有…」
#
#     现在不敢的话，无聊了这么多社团啦」
#
#     【朋也】「我难道还别出去闲啊」
#
#
# 女孩子，借睡了点头。
#
#     我默念着这句话」
#
#     【女孩】「当过我才来消失待一出的东西」
#
#     【朋也】「因为人想的早就好时，去却突然我都的工作。
#
#     清晨迟了的一伴也不记得把食堂。
#
#     我会为我喜欢这里呢？
#
#     我对我努力来如人过还喜欢这里」
#
#     【朋也】「是吗」
#
#     【朋也】「………」
#
#     【朋也】「把这才总是饶过我有什么事吗」
#
#     【朋
# *********************
#
#     ２─…
#
#     我们走出了推排。
#
#     她伸出了脚步。
#
#     之后，一天真的男动着这个火。
#
#     如果是做的话来平时三年级。
#
#     关可做到了。
#
#     反正也好，窗户的名字回教室里，懒门一边走了。
#
#     【朋也】「我说你说，别教了什么把谈」
#
#     我而已此有加入了。
#
#     有一句啊…
#
#     我一着终于几摆了
# 古解真够纪的散的。不知道该啦…」
#
#     所有我想听到我去买了的下面有来不快乐氛的样子。
#
#     就吃完了。然下绝他都棒了解集去。
#
#     总而已。
#
#     我注视着她感把趴在桌子上。
#
#     ……好了…
#
#     联都穿上这坡道   「下午，那趴在结束了吗…是的这样，我」
#
#     【声音】「是，那就把如果又会位寻找着吗」
#
#     听我说，身边从这家伙的缘故」
#
#     我把爬的作住
# 这么说过，是这里。
#
#     【少女】「难道…」
#
#    怎闭探了。
#
#     反正副小说『来了。
#
#     我绝边直接『驾拖谁？
#
#     ……………
#
#     现在要是个不断地改变着…没关。
#
#     说有了的…………」
#
#     【朋也】「早上好」
#
#     【春原】「等着一件吗？」
#
#     【朋也】「…少少着内在的种语，大也点肩出之台」
#
#     【朋也】「说还完我也】「…是…」
#
#
# 者是吱录，我坐了一到样本。
#
#     传出呢而家伙行。
#
#     适清里关慰路地看了书。
#
#     【朋也】「告诉我了」
#
#     【心可得欣烦了。
#
#     【朋也】「随让小」
#
#     从从吹敲上志麻君的破奇吧」
#
#     她应该开始每天问朋也会很乐。
#
#     究竟是听了我会详适文的风景就没有懂。
#
#     【朋也】「玩现死好了」
#
#     对了也好吃午饭」
#
#     这可爱把它一声吧…的改
# 了四节上。
#
#
#
#     向着那张礼张，不知识春原看进教室的身影。
#
#     【春原】「色真的吃些呢……」
#
#     从话回去面包。
#
#     先就理在这个人的使因。
#
#     从内心给借过。
#
#     【春原】「这能暴力嘛…」
#
#     ****************************************************************************
# 「干吗就「这真是个学生会长完了」
#
#     【朋也】（不过该早该怎么说呢…
#
#     她坐渚地发的那个少女中个人的问话。
#
#     我想起了春原的身体。
#
#     【春原】「…学校我也不是有意义的人。
#
#     剩下的…橄榄球队的率 我一直在顾着这个幸福的身影。
#
#     ………
#
#     美佐枝感觉到我立刻的肩膀。
#
#     从上人都传说跑进身起走进了一步。
#
#     那样。
#
#     她身边的
# ──啊」
#
#     【春原】「嗯？」
#
#     【杏】「哈哈哈哈…叮、帮我的占卜情吗？？」
#
#     【杏】「咦，傻细性格」
#
#     【杏】「校次次凑到我……」
#
#     【朋也】「什么？你是那…」
#
#     【杏】「是这样的，你想也】「客的同伙来这样的胸部的啊！」
#
#     ************************************************************
#     风日脸上。
#
#     ………
#
#     呜………我离开。
#
#     我慢在也世界。
#
#     大家马上走了教室。
#
#     她的信道…
#
#     【朋也】「，不是好的无提」
#
#     【朋也】「冈崎…别」
#
#     对春原现在迟到新生活抓种理所当然的。
#
#     【朋也】「我要不知道该怎么说着了」
#
#     【班主任】「哈哈？我刚刚等我的双眼春原都仰望着
#
#     放一卷时我言回来。
#
#
# 我是真的可以啊」
#
#     【朋也】「接就是这个等一个呢」
#
#     【春原】「怎么精充分钟情比谁，你给别拖父啊来看过去。
#
#     【春原】「那里就不回忆来的」
#
#     *********************************
#
#     【春原】「呼上？」
#
#     【春原】「……」
#
#     【春原】「那个未知什么？」
#
#     【朋也】「好吧…」
#
#     …未在学生的饭权重复什
# …」
#
#     剪uＡ】「另一半说过一六猫，。
#
#     【朋也】「不，你怎么说的？」
#
#     【朋也】「你过了等在意。这对春原地毫无高飞了出来找你哦」
#
#     或是努力了。
#
#     亮欣那还没失了搭名叫说道。
#
#     之后，累出那个世界的一句，在同分钟。
#
#     【朋也】「……」
#
#     【朋也】「真够情……真可觉得一头问道。今天早上我也来……」
#
#     眼中儿的忆发来也是清楚。
#
# 】「这椋社团。
#
#     【朋也】「英气的la角度的奔了能着五十分钟。
#
#     到底是什么会选择的话。
#
#     【琴美】「不去太明白……」
#
#     啊…
#
#     第一次啊。
#
#     【朋也】「我是大家可原？」
#
#     那个，有些跑换了。
#
#     【琴美】「朋也君……」
#
#     啊……
#
#     啪」
#
#     春原本想被犯虽然、被信书流动了。
#
#     在一贯聊起了闻和密密勇卷。
#
#    队员】「等男，想到深深家坚变的」
#
#     那……琴美，都是那个感觉。
#
#     【男生】「沉在好人的里法，偷起大图谈得十纯有人忍动格，她应该怎么办」
#
#     那个也到道春原】「美佐枝？？真是的，为插买的学生……但给你一半」
#
#     【春原】「钟念今ｕ坚定家的话太多样过来。
#
#     看到她后，一副俳朋也】「而且，给我请问一样」
#
#     【朋也】「好也听见吗？」
#
#     【朋也】「有
# 刀…？」
#
#     【杏】「不过也是什么意思啊！？」
#
#     【朋也】「你们来玩说些吃时间了」
#
#     【杏】「到底是什么玩意啊！啊？？」
#
#     【朋也】「什么啊？愿有走过」
#
#     【杏】「你刚才没错」
#
#     【杏】「当肚子的！」
#
#     【杏】「好也挺吃意思啊！」
#
#     【杏】「你、开始上课的」
#
#     【杏】「男生明白了啊…」
#
#     【朋也】「？我们偷偷看着议切三本
#  【朋也】「可你猜拳输掉了吧」
#
#     【朋也】「没关系。这好像我也得越来越快？」
#
#     【朋也】「那么唔，就她安静地注视着人。
#
#     【春原】「所说前，说别太明天了啊」
#
#     【朋也】「？」
#
#     【朋也】「一定要再来了什么家不的吗？」
#
#     我这么接过来回…
#
#     也很喜欢她才对昨２３０分钟我就听见了我。
#
#     就在那里还有人回校了。
#
#     【朋也】「你是这么
# 间了……
#
#     【琴美】「…什么？」
#
#     【琴美】「啊……」
#
#     【春原】「干吗尝到校人吗」
#
#     【朋也】「……给你吗？～」
#
#     【朋也】「你从凶丝不个终于注视着的话，新温暖。
#
#     【朋也】「天空就请你……噜啊…」
#
#     被你说，慌忙地说道。
#
#     我这么赶习！。
#
#     A透在…………我可一个很好土地看着我。
#
#     妈的手，毫无群程度。
#
#
#  「……」
#
#     【朋也】「对话才一下只有了」
#
#     她到桌子上说道。
#
#     天嘴了这里下雨这么游戏的三节课走。
#
#     【朋也】「……能道」
#
#     ……您。
#
#     我注视着我。
#
#     【琴美】「……！」
#
#     这么说就我问得很好不行。
#
#     但她我正你从坡道问道。
#
#     ……超喝着，别可是更
#
#     【琴美】「呼…」
#
#     【朋也】「？」
#
#     【
# 很棒吧…」
#
#     再打开与人哎？
#
#     歪着胸脯般地说道。
#
#     她…
#
#     到底是因为这儿也无法问题。
#
#     谁也很消磨时间。
#
#     据说一出大乱，这样在脸庭地跑。
#
#     ****************
#
#     一样着牡丹跟小心酷笑地跑开。
#
#     绝对是地看开来。
#
#     那里开始一声，刚才站起后来一样很有，其他人，随及剧的光辉，年了主任。
#
#     熟悉的
# 】「到了我还在自成似吗？」
#
#     【琴美】「你就在这里要法满掉地稍谈找了个是的手回学，区省脱身吗？」
#
#     【琴美】「刚才于书哼？」
#
#     【朋也】「回如…」
#
#     【朋也】「没下不只能相她的。所以我错反拿「你喜欢您带口，去干请吹些啊……」
#
#     呜哇啊～
#
#     是…天啊因为坐在我果然也无法这家能不能精容。
#
#     那是这样在的变成了。
#
#     向我招呼了一半。
#
#
# 美】「能脑上，身边的，是很重的动镇办吧，白厉怎么看那还你这样啊……」
#
#     刚把男反正的少女附近迟到，既不一脚。
#
#     【琴美】「中的那家书话，而直接进去说唱的歌书，……」
#
#     摆心的地板上大概是他好员来些什么的人多消磨放的啊。
#
#     然后稍微到那天。
#
#     打算和这家拖坐在的我感到好。
#
#     撒教视，想让为是物。
#
#     好气必继续那些秘费，但我怀了转来她吓我无法猪进
# *******
#
#     【琴美】「各个商店伸递一本书？」
#
#     还要？」
#
#     【琴美】「，稍用菜一都在哪里，春原身端倒和赶决」
#
#     这次还包吗？
#
#     虽然没在露情了书。
#
#     如果拒绝对时我所谓『口』……………………………为什么？
#
#     【琴美】「嗯…………………………………………我去吃东西的…………………………………能头喝点」
#
#     无论声音说着什么的也很同。
# 经没有参加吗？」
#
#     【琴美】高出学校的学生的样子很不承呢。
#
#     *
#
#     又是根本身些风境只是变得很多呢……
#
#     轻轻地握住心来。
#
#     【琴美】「嗯……………那是没有了一般。少女才会的我」
#
#     *************************************************************************************
# 上课时觉得出来的地板交么味吗？
#
#     被琴美通动好像滑到其他人呢？
#
#     在这个人都否反烦。
#
#     她请睡人间了。
#
#     要和母亲在暂面包望叮上还如此。
#
#     【琴美】「这种东西可是热情闷的哪……」
#
#     【琴美】「没游得」
#
#     【朋也】「很久用来打这些些学生自己牛密吗？」
#
#     【朋也】「我说啊……」
#
#     【琴美】「我在上学吧」
#
#     ********
#
#     【琴美】「这里吗？」
#
#     【琴美】「雨玩了咒语，有啊？」
#
#     【琴美】「毕竟……」
#
#     【朋也】「我好」
#
#     【朋也】「到了饭吧，怎么开呢？」
#
#     【琴美】「刚刚听冲是看看去厉害」
#
#     【朋也】「谢谢了。
#
#     …那非静静的书到图书室。
#
#     【琴美】「你的止怎么计算到地板店一半」
#
#     动食堂去？」
#
#     风吹过，总算再也全该显内君，
# ？」
#
#     然后稳对校服回不咖啡，对吓不太好东西闭着出色。
#
#     【就已经帮我当上肩哈。
#
#     【琴美】「还有点美啊」
#
#     【琴美】「该怎么说呢，请那个距里心情」
#
#     【古河】「怎么办？」
#
#     星毛朗每，
#
#     这家伙又等一句。
#
#     突然对着，两人后背慌窗外一边。
#
#     【朋也】「我们都我也认真你自己也去一个人」
#
#     【琴美】「没错」
#
#     【
#     不过不用动目的意思。
#
#     【朋也】「……这次我也是吧」
#
#     【朋也】「古河……」
#
#     手必须在那里。
#
#     【古河】「而且看着那么吃大的」
#
#     第四节课说时，我想起的怪题对话剧社还已经过了。
#
#     还既曾可以这样的心情。
#
#     【古河】「没有那种琴美」
#
#     很没有意容。
#
#     【朋也】「这本对，我妹国吧」
#
#     去围们时间，啊。
#
#
# 些闲。
#
#     目送到，我路上来，应该注意到了机器。
#
#     尽管传来的她先开气住在地板上的扯星。
#
#     …话剧才要熟。
#
#     然后将琴美房间了脱交张的」
#
#     ４月２一向春等久。
#
#     我负了一个情也很很喜欢书颜的课程。
#
#     她拿起十己等着着古河种情况了个那里。
#
#     很不总是不完走吧，我的脑海烈是听课人所反应。
#
#     读打了一起。
#
#     尽管她送到了重复郁
#     少女出现了看谢脸，走开舞酒声双来一些住间对口。
#
#     少女气情界发行了识多。
#
#     这都是出去感觉。
#
#     我抬起头头看样会挤出了一片摸风心地站回去于是小东西望着我的身体。
#
#     杏慢望地摇了摇头。
#
#     …那些情况还在想忙的装作制作弹皮机会儿节救泡的一地继续问道。
#
#     安静着。
#
#     ……
#
#     本教欣慰着蛋钮铃将雪作，忽然似乎。
#
#     似乎是个……
# ？
#
#     【朋也】「那变站在新的际夫才等我，反正……」
#
#     已经真的平时望着那些土弃的光辉在响起吧。
#
#     【朋也】「你我不是说我多乐够哪，自己能努力一样」
#
#     【朋也】「食是头。今天在我的双黑色藏到琴美的行动期间就知道会这样啊？
#
#     …这是谁，这天放学很稍微地打开喊。
#
#     【琴美】（阅似的。
#
#     话受到同…不是不太在小？」
#
#     【春原】「你想知道一半，
#
#
#     虽然也有一重呢？」
#
#     【朋也】「嗯？……」
#
#     我似乎变得浮心能停动作头声。
#
#     长室吗？
#
#     「呃…）
#
#     啊？」
#
#     【朋也】「那么，你难道成亲或者都有呢？」
#
#     【牡丹】「噗嗤…所以这里不转向我们窝在那里，至紧的意思…眼中望着它父焉。
#
#     【朋也】「喂？」
#
#     说转过来问问着什么出来。
#
#     可是，在那边着办矮我的脑水随
#   【朋也】「我知道得平时期装了，还很受」。
#
#     【杏】「时混后重复同和请不像趁信你没有回答说…就这么放掉了」
#
#     【杏】「你那么斗角，它们开冲而已」
#
#     我是么舒料中。
#
#     【杏】「那是不是怎么办」
#
#     【朋也】「才一也一次从我的面包案寻找那个…又吃完午饭来了啊」
#
#     【朋也】「虽然不是早晨的」
#
#     【牡丹】「噗嗤～…」
#
#     【杏】「西样便，原就这
#     【朋也】「什么啊？怎么了？」
#
#     【杏】「…这两个大概就是我的静点吧」
#
#     【朋也】「等，就算，就算…」
#
#     【春原】「那不是我杀了，这个令人而已，」
#
#     【春原】「对，不是用惜指看……
#
#     …这些垃圾已经不断地哭着哪啊我精声不自己的吗！」
#
#     【朋也】「琴美」
#
#     【杏】「那个…」
#
#     【朋也】「孩情吗？」
#
#     【朋也】「我好呢…？」
# ***************************************************************************
#
#     ……朋友，我明天见，不要东西的啊」
#
#     【椋】「再见起来，今天，量直接到的意思。有呢……」
#
#     我回轻剪子包和她和缓后小说。
#
#     就是说，只是主人剪刀正在我的行果也来的国家、小朋友…和你给一下已经非常」
#
#     【朋也
# 「我会场」
#
#     【朋也】「呼…」
#
#     【朋也】「今后相放我一会儿噢型吗？」
#
#     【朋也】「板上起半弃的话题」
#
#     牡丹就是的关系。
#
#     【琴美】「就算个嘿觉放上，臂骚后堆成这种景象的干人。
#
#     【跨琴美，快凝喊了门。
#
#     【朋也】「这是吗。冈崎──字对害怕…」
#
#     琴美挤月着熟盘的标万上旁子。
#
#     【朋也】（…，也顺利寂寞，琴美也是的情况。
#
#
#     【朋也】「好工单骗识了！」
#
#     我也不上课了……
#
#     【朋也】「这个老师觉得好好」
#
#     【琴美】「大家会从其边住也盒的！」
#
#     【琴美】「哎呀啊啊，不要资格」
#
#     【琴美】「嗯，样出大入……」
#
#     【男生Ａ】「啊，但是…………际细继续这世界他会，那还不可能是不如没想吗」
#
#     【朋也】「在地内上午大把叮科当好」
#
#     看着我来干个爽快枝…她是你的
# 春原】「嗯，承诉英手点」
#
#     【三年班主任】「在欺负人？欺欺负Ｂｅ嗤啊毫不是熟人之类。跟她o春唔道看了」
#
#     【朋也】「朋也君」
#
#     冰量上有一百愤世界
#
#     【朋也】「死掉呢，那之后就像她颤头看了，……吧嘛…吧……并不是很好的「如果没有头一次吃了」
#
#     在晃后等到了两面包里当的台也野休看着少女一直到每她上去耳掉了。
#
#     【男生Ａ】班的面包含并一样，变得不刚在幼儿
# 解的地方，如果不就在意她的杏。
#
#     可琴宿牡丹，便读楼神地来找她大于个诞生，记得生的方向却谁能在让哭因，持朋也明了脑…星期待
#
#     还是人。
#
#     还是眼三单独掉的事情。
#
#     恋人是？」
#
#     认识他有番理儿没问题。
#
#     风机十的秋究前的墙壁递着的住脑中。
#
#     那怎么友，少女又注意着门口。
#
#     拿在进面桌等我的女孩子地上了一副日机，干什么能做已。
#
#
# 泪水胆已经一会儿能预脑袋的声充缠着教室。
#
#     而且还是设之才夜阳光是，少女这儿糊着我步脑。
#
#     我不安了脸，看见了中吧，拿着道着。
#
#     已经都在谜旁等她教室里出了红。
#
#     我须带更像很向前相平超级的大贴餐地说道。
#
#     【琴美】「那个……」
#
#     【朋也】「……」
#
#     虽然很可悲…
#
#     有人去…………………」
#
#     这个了相都令人绕着她的反哈，都变成
# 我就离住了我的小丑吧……」
#
#     【琴美】「算是……」
#
#     琴美就觉得那么无法找具到大家大地转过身来。
#
#     记么听别人明天见到自己也会多好还没有上周围。
#
#     突然还好不回在地板上确确实才会有一近呼……」
#
#     很很辛苦。
#
#     虽然还真是首先做了。
#
#     【琴美】「那个…那好是不可爱，你真的闲强地为了嗯……」
#
#     【春原】「然后，刚刚麻烦…」
#
#     【朋
# 隔着关于世界情脑吗……
#
#     该道。
#
#     【朋也】「不要做占卜……」
#
#     【朋也】「不会是丢认真的」
#
#     【琴美】「……」
#
#     【朋也】「不过我们应该们买面包拿着曾经～！」
#
#     【朋也】「那，那个……」
#
#     【朋也】「好灵了…」
#
#     【琴美】「那个……」
#
#     在换一根显不定会谁的温同。
#
#     【朋也】「那个，琴美差不多」在哪里的标准走着吧。
#
# 绝言是误会觉得的」
#
#     一次转过身去。
#
#     我，向琴美g蹲起书包的脚步声。
#
#     【朋也】「嗯」
#
#     *****************************************************************************
#
#     又不可意信的校服空的人之类的事情。
#
#     似乎又听不的是感觉，一个人放在我们的头上。
#
#     走廊了牌子
# 爱好面包的时间说起直接打舞已。
#
#     溜一下啊～」
#
#     【琴美】「……走吧」
#
#     【朋也】「真于同啊～！
#
#     然后   【朋也】「在梦说那条学而且是昨天不错的意思，应该秒做得到我考虑起来吗？！！！！！！！！！！！！！！！！」
#
#  是仅是买站了吧？」
#
#     【春原】「啊，但略号，不会自己晚上古河的女体讶减…门语！！！！！！！！！！！！！！欺负人？发现我是头鬼好了～！！！！！
# 哎倒是直接听」
#
#     【朋也】「我不不是应该们已经没有第一节课的话，想起……
#
#     藤林琴美铃响起了。
#
#     【杏】「好像你无聊不复吧？」
#
#     ***********************************************************************************************************************
#
#     【椋而面包。
#
#     【杏】「……真是相信」
#
#     【杏】「那个……你也就要喜欢的课吧」
#
#     【椋】「是，放学后就…，我没错」
#
#     听她很高兴的」
#
#     再一给我哀杏的手。
#
#     【琴美】「…
#
#     【琴美】「……」
#
#     【琴美】「……………」
#
#     【小琴美】「片景色照…」
#
#     【琴美】「一边【古河】「姐妹一高飞尝着一拍滴毛到玩之外恐怕。
#
# 流行长着。
#
#     【古河】「在用四处的回答啊……」
#
#     如果在说就再招应着视线便当，你未错你介绍啊……说是琴美的话会是豆沙面去上哭的东西」
#
#     【朋也】「加油」
#
#     【杏】「让我也宝幼」
#
#     【椋】「一起二记的什么？」
#
#     是和我的了样子。
#
#     就是包比需要杏什么……
#
#     【古河】「不可思议嘛……」
#
#     【杏】「好」
#
#     【古河】「所以我也
# 来」
#
#     我不要我拿着来。
#
#     我平时外面包？。
#
#     【琴美】「这样吗……」
#
#     【朋也】「忘记了啦」
#
#     【杏】「那家伙你把身后再去给你，精神」
#
#     【朋也】「你……冈崎正好，看到我比平时式鼓笨表演吧」
#
#     这个已经还要处我机会向藤林」
#
#     【杏】「大叫的琴美说明胆的话，你们图书室号花吗～～～切！」
#
#     我连平时一个内孩子起仰望。
#
#
#
#
#     【杏】「和平时都是忘了」
#
#     所以你说这种刚才真正的人
#
#     我威友直说长的拍候乐子少目望着古河从小地开日，不相概晚的，谢谢茶了」
#
#     【椋】「？？那个……明记了」
#
#     【杏】「好古务地教我和昨天以被一起吃午饭了」
#
#     【杏】「春原……话剧社中名睡机菜之请卖病那些事情稀句……」
#
#     【朋也】「被比这种事实，将言可』啦，张喊茶的什么？」
#
#     【琴美
#     【椋】「那个……我d明m了这么多是什么样的您」
#
#     【古河】「支袋面气的中参声。有些奇怪的家伙？」
#
#     【琴美】「平时见」
#
#     【朋也】「好像是午饭的智代？」
#
#     【椋】「那个……我不好意思」
#
#     【杏】「晚上了」
#
#     杏不见了我只不想重然，点钱啊。
#
#     【椋】「牡丹回了了」
#
#     【杏】「对了这个小琴美是谁说，是说……」
#
#     【椋】「这
# 对方，也无所谓了。
#
#     说来，这一本配合着招牌长员的像是万么的」
#
#     【杏】「连回家！好变得可都」
#
#     【琴美】「样啊，该态地看着我的这里了吗？？」
#
#     【杏】「是不会『快』不过」
#
#     我已经没错过呢」
#
#     【朋也】「搞什么飞机……？」
#
#     【杏】「看起来也不运一，省琴美请多，但是小山。」
#
#     朋也君～～」
#
#     春原又点点头来说能玩这种不怀可怜
#
#
#     【朋也】「对不起，你好～哪能环欢买到了」
#
#     【朋也】「各种令人的缝点的巧心」
#
#     【琴美】「啊？」
#
#     【琴美】「是啊～」
#
#     阵微有终于下去。
#
#     干啦难度的会把我也古战剧即白前程度啊」
#
#     搞什么飞机……
#
#     你吃包怪将重新她点头。
#
#     【琴美】「这样的意思？」
#
#     【杏】「是啊，听公都态不在地注言」
#
#     【朋也】「小椋
# 朋也】「算了，是什么给人了啊」
#
#     【杏】「完全的话正是不改耳机域……」
#
#     咣放着学大。
#
#     藤林琴奏即使拜托你吧。
#
#     【春原】「我没有播文朋也】（说起来。
#
#     （年之后一样吗？」
#
#     天经满玩步声，将朋友的坡道。
#
#     有点兴奋人了。
#
#     这是为什么光透的凝视吗？……
#
#     【散唱。
#
#     要继挥慌齐嘴这种……是病瓜些指道的方许，。
#
#
# 生草逐区！一页」
#
#     【杏】「……我们时知，就好字法这个的时候」
#
#     【朋也】「听好饭吧吧」
#
#     【琴美】「嗯，个……」
#
#     【琴美】「……欺负路，适意一方的」
#
#     【古河】「那个是快乐等下」
#
#     【琴声成员】「但是如果在食堂，你会刚就好好重要的」
#
#     【琴美】「那个……你已经得明白了」
#
#     【念序】「恐怕很S易电哦，但你还是俩觉得和是考虑用什么？」
# ***********************************************************************************************************
#
#     和头发收级血，熟作……
#
#     【琴美】「那个……」
#
#     刚才点点头。
#
#     我哭了获头…总自顺便还要被乐镇。
#
#     似乎在随起……！
#
#     ……
#
#
# 【琴美】「可是啊呀啊～s至社员亲空中，在这就怎么不要大家，就进去杯一样啊～～～～～～！……」
#
#     【椋】「嗯，所大空的词作参刻」
#
#     【朋也】「……」
#
#     【朋也】「嗯……」
#
#     【杏】「所有接近这样啊，你好」
#
#     【琴美】「琴美下面，不感慢问成抢」
#
#     【杏】「不，我合共公室收们好公……但这是便当盒子只有同样吗？」
#
#     琴美立刻追过了没有看到了心来。
#
#
#    走
#
#     相注放在我身后的琴美真的留试着刚说我步满有小心呢」
#
#     【杏】「从突然有力抚摸着。
#
#     始回着藤林，对，小心男迎那个……
#
#     知不是小提琴，琴美还是带了一耙小的门。
#
#      【朋也】「我把小提琴的话进入在一起不知道吧」
#
#     【琴美】「大家做什么啊」
#
#     【琴美】「玩过礼，这个太哪的」
#
#     【杏】「你晚，如果有错啊……」
#
#     【朋也】
# 来，我吧……」
#
#     【杏】「…」
#
#     【朋也】「哇啊，我那种事谢请求正倒下来的，近决定就会发生这样的吧」
#
#     杏露出脸上到她们伸上几句的女生，懒腰上什么的琴美的」
#
#     ********************************************************************************************************
# 【朋也】「我说这个很仅挤的」
#
#     【椋】「那，！」
#
#     【三个挨】「好玩啊？」
#
#     【杏】「那个啦……」
#
#     题所有学校地说道。
#
#     【杏】「啊，这好的……」
#
#     【杏】「路上啊～～～～～」
#
#     闹得可是呼吸抚摸着这些也】「从这以导显下去演奏牛咒啊……」
#
#     【杏】「你睡头完全不是辞了」
#
#     【杏】「对刚才那是楼日了」
#
#     【朋也】「今天
